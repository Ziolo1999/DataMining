# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway, chi2_contingency, mode
from sklearn.model_selection import RepeatedStratifiedKFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc
from matplotlib.legend_handler import HandlerLine2D
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from catboost import CatBoostClassifier, Pool
import pickle
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
import catboost as cb
from sklearn.calibration import CalibratedClassifierCV, CalibrationDisplay
from matplotlib.gridspec import GridSpec

# %% [markdown]
# ## Data preprocessing ###

# %%
DATA_PATH = "data/existing-customers.xlsx"
data = pd.read_excel(DATA_PATH)
print("\nColumns:", data.columns, "Row ID is unnecessary therefore it was decided to drop it.", sep="\n")
data = data.drop(columns=["RowID", "education-num"])
# Out:
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Columns:
# Index(['RowID', 'age', 'workclass', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class'],
#       dtype='object')
# Row ID is unnecessary therefore it was decided to drop it.

# %% [markdown]
# ### NA investigation

# %%
nas_count = data.isna().sum(axis = 0)
print("\nTable below represents number of NA values for each column.", nas_count,  sep="\n")
# Out:
# Table below represents number of NA values for each column.
# age                  0
# workclass         1836
# education            0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# class                0
# dtype: int64

# %% [markdown]
# As it is noticeable only three variables consist NAs. All of them are nominal therefore it was decided that during learning part use a Simple Imputer with most frequency strategy.

# %% [markdown]
# ### Categorical Variables Analysis

# %% [markdown]
# As data consists both categorical and numerical variables it was decided to start with categorical ones. Firstly, I checked how many unique values has each variable. Afterwards, some barplots were plotted. They allowed to investigate the values frequencies for each variable.

# %%
data.rename(columns = {'marital-status':'marital_status', 'native-country': 'native_country',
                            'capital-gain':'capital_gain', 'capital-loss': 'capital_loss', 'hours-per-week': "hours_per_week"}, inplace = True)

cat_cols = list(data.dtypes[data.dtypes=="object"].index)
num_cols = list(data.dtypes[data.dtypes=="int64"].index)
dep_var = "class"
cat_cols.remove("class")

print("\nCategorical variables: ", list(cat_cols), "\nNumerical variables: ", list(num_cols), sep="\n")

unique_table = data[cat_cols].nunique()
print("\nTable representing number of unique attributes for each categorical variable: ", unique_table, 
      "\nTo preprocess data correctly it was decided to take a closer look at each variable individually.", sep="\n")

fig_row = int(np.ceil(len(cat_cols)/2))
fig, ax = plt.subplots(fig_row,2, figsize=(20, 20))

indx = 0
for col in unique_table.index:
    freq_table = data[col].value_counts()/len(data[col])
    
    if indx%2 == 0:
        sns.barplot(ax=ax[int(indx/2),0], y=freq_table.index, x=freq_table.values, palette="crest")
        ax[int(indx/2),0].set_title(col)
    else:
        sns.barplot(ax=ax[int((indx-1)/2),1], y=freq_table.index, x=freq_table.values, palette="crest")
        ax[int((indx-1)/2),1].set_title(col)
    indx += 1
plt.show()
# Out:
# Categorical variables:
# ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'native_country']
#
# Numerical variables:
# ['age', 'capital_gain', 'capital_loss', 'hours_per_week']
#
# Table representing number of unique attributes for each categorical variable:
# workclass          8
# education         16
# marital_status     7
# occupation        14
# relationship       6
# race               5
# sex                2
# native_country    41
# dtype: int64
#
# To preprocess data correctly it was decided to take a closer look at each variable individually.

# %% [markdown]
# The figure above revealed that some variables aren't proportionally distributed. Especially, variables like native country, workclass, education and race. Therefore it was decided to focus on them in next steps as it was expected to do some data manipulation there.

# %% [markdown]
# #### Workclass

# %% [markdown]
# The table below represents the frequency distribution of the first variable, workclass. Its analysis would help us to determine what manipulation should be done to increase performance of our model.

# %%
freq_table = data["workclass"].value_counts()/len(data["workclass"])
print("Workclass", freq_table, sep="\n")
# Out:
# Workclass
# Private             0.697030
# Self-emp-not-inc    0.078038
# Local-gov           0.064279
# State-gov           0.039864
# Self-emp-inc        0.034274
# Federal-gov         0.029483
# Without-pay         0.000430
# Never-worked        0.000215
# Name: workclass, dtype: float64

# %% [markdown]
# We can notice that our data is slightly imbalanced as almost 70% of customers are private workclass. Now let's see how it is distributed if we take into account our dependent class.

# %%
freq_table = data.loc[:,["workclass", "class"]].value_counts().reset_index()
sns.barplot(data = freq_table, y="workclass", x=0, hue="class", palette="crest")
plt.show()

# %% [markdown]
# We can notice that in most of groups classes are unevenly distributed. Moreover, as we previously noticed most of our data is represented by Private group which dominates our sample. Moreover, we have three small groups which represent different types of government workclass. Ultimately, I decided to merge them into one group. Additionally, groups Without Pay and Never Worked are not represantative as they constitue less than 0.001% of customers. At the beginning there was an idea to drop these observations, but after experimenting with them I decided to keep them as they might give some information about data.

# %%
# Group Merging
gov = ["Local-gov", "State-gov", "Federal-gov"]
data["workclass"] = data["workclass"].apply(lambda x: "Gov" if x in gov else x)

# # Dropping not representative observations
# indx = np.where((data["workclass"]=="Without-pay") | (data["workclass"]=="Never-worked"))
# data = data.drop(index=indx[0])

# %% [markdown]
# #### Education

# %% [markdown]
# Similar analysis was done for education variable.

# %%
freq_table = data["education"].value_counts()/len(data["education"])
print("Frequency Table: Education", freq_table, sep="\n")
# Out:
# Frequency Table: Education
# HS-grad         0.322502
# Some-college    0.223918
# Bachelors       0.164461
# Masters         0.052916
# Assoc-voc       0.042443
# 11th            0.036086
# Assoc-acdm      0.032769
# 10th            0.028654
# 7th-8th         0.019840
# Prof-school     0.017690
# 9th             0.015786
# 12th            0.013298
# Doctorate       0.012684
# 5th-6th         0.010227
# 1st-4th         0.005160
# Preschool       0.001566
# Name: education, dtype: float64

# %% [markdown]
# Based on the table above we can notice that education variable is more widely distributed. However, it also gives an impression that there are categories which practically represent similar level of education. But before we come up with any conclusions it was decided to take a closer look at the barplot.

# %%
freq_table = data.loc[:,["education", "class"]].value_counts().reset_index()
sns.barplot(data = freq_table, y="education", x=0, hue="class", palette="crest")
plt.show()

# %% [markdown]
# The figure above confirmed our expectations. It is noticable that for all customers who had compulsory education, the class distribution is similar which confirmed thoughts above. Therefore, it was decided to group all education levels that are compulsory into one group. Secondly, it was noted that all Associates levels should be also also grouped together as the classes are also distributed similarly. There was also a thought of merging Bachelors and Some College together, but it was recognized that there is significant difference between attending to college and getting degree.

# %%
# Merging
compulsory = ["11th", "9th", "7th-8th", "5th-6th", "10th", "1st-4th", "12th", "Preschool"]
data["education"] = data["education"].apply(lambda x: "Compulsory" if x in compulsory else x)

assoc = ["Assoc-voc", "Assoc-acdm"]
data["education"] = data["education"].apply(lambda x: "Associate" if x in assoc else x)

# %% [markdown]
# #### Race

# %%
freq_table = data["race"].value_counts()/len(data["race"])
print("Frequency Table: Race", freq_table, sep="\n")
freq_table = data.loc[:,["race", "class"]].value_counts().reset_index()
sns.barplot(data = freq_table, y="race", x=0, hue="class", palette="crest")
plt.show()
# Out:
# Frequency Table: Race
# White                 0.854274
# Black                 0.095943
# Asian-Pac-Islander    0.031909
# Amer-Indian-Eskimo    0.009551
# Other                 0.008323
# Name: race, dtype: float64

# %% [markdown]
# From the table above we can notice that our data is dominated by White customers. However, if we look at the bar plot we can notice that the difference of the earnings distribution is not as significant. Therefore, it is expected that this variable would not have any strong impact in our model. Ultimately, it was decided to group all other races than White into one group.

# %%
race = ["Black", "Asian-Pac-Islander", "Amer-Indian-Eskimo", "Other"]
data["race"] = data["race"].apply(lambda x: "Other" if x in race else x)

# %% [markdown]
# #### Native Country

# %%
freq_table = data["native_country"].value_counts()/len(data["native_country"])
print("Frequency Table: Native Country", freq_table, sep="\n")
# Out:
# Frequency Table: Native Country
# United-States                 0.895857
# Mexico                        0.019748
# Philippines                   0.006081
# Germany                       0.004207
# Canada                        0.003716
# Puerto-Rico                   0.003501
# El-Salvador                   0.003255
# India                         0.003071
# Cuba                          0.002918
# England                       0.002764
# Jamaica                       0.002488
# South                         0.002457
# China                         0.002303
# Italy                         0.002242
# Dominican-Republic            0.002150
# Vietnam                       0.002058
# Guatemala                     0.001966
# Japan                         0.001904
# Poland                        0.001843
# Columbia                      0.001812
# Taiwan                        0.001566
# Haiti                         0.001351
# Iran                          0.001321
# Portugal                      0.001136
# Nicaragua                     0.001044
# Peru                          0.000952
# France                        0.000891
# Greece                        0.000891
# Ecuador                       0.000860
# Ireland                       0.000737
# Hong                          0.000614
# Cambodia                      0.000584
# Trinadad&Tobago               0.000584
# Laos                          0.000553
# Thailand                      0.000553
# Yugoslavia                    0.000491
# Outlying-US(Guam-USVI-etc)    0.000430
# Honduras                      0.000399
# Hungary                       0.000399
# Scotland                      0.000369
# Holand-Netherlands            0.000031
# Name: native_country, dtype: float64

# %% [markdown]
# Just by looking at the table we can notice that data is strongly imbalanced. Most of our customers are Americans. It means that data is practically homogenous and any useful information could not be taken from this variable. Therefore, it was decided to drop it.

# %%
data = data.drop(columns=["native_country"])
cat_cols.remove("native_country")

# %% [markdown]
# ### Numerical Variables

# %% [markdown]
# To analyze numerical variables it was decided to plot density distributions for each class. Based on them further investigations could be done.

# %%
num_dscrb = data[num_cols].describe()
print("\nBasic statistics for numerical variables:", num_dscrb, sep="\n")

fig_row = int(np.ceil(len(num_cols)/2))
fig, ax = plt.subplots(fig_row,2, figsize=(20,20))
indx = 0
for col in num_cols:
    rgb = (np.random.random(), np.random.random(), np.random.random())
    if indx%2 == 0:
        sns.kdeplot(ax=ax[int(indx/2),0], data = data, x=col, hue="class", fill=True, color=rgb, alpha=.7)
        # ax[int(indx/2),0].set_title(col)
    else:
        sns.kdeplot(ax=ax[int((indx-1)/2),1], data = data, x=col, hue="class", fill=True, color=rgb, alpha=.7)
        # ax[int((indx-1)/2),1].set_title(col)
    indx += 1
plt.show()
# Out:
# Basic statistics for numerical variables:
#                 age  capital_gain  capital_loss  hours_per_week
# count  32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647   1077.648844     87.303830       40.437456
# std       13.640433   7385.292085    402.960219       12.347429
# min       17.000000      0.000000      0.000000        1.000000
# 25%       28.000000      0.000000      0.000000       40.000000
# 50%       37.000000      0.000000      0.000000       40.000000
# 75%       48.000000      0.000000      0.000000       45.000000
# max       90.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# Based on the statistics and plots we can notice that there are some outliers which would be investigated later. Secondly, we can notice that the distributions for each variable slightly depends on the class. Therefor, they might be helpful in our model.

# %% [markdown]
# #### Outliers analysis

# %%
fig_col = int(np.ceil(len(num_cols)/2))
fig, ax = plt.subplots(2, fig_col, figsize=(20,20))
indx = 0
for col in num_cols:
    rgb = (np.random.random(), np.random.random(), np.random.random())
    if indx%2 == 0:
        sns.boxplot(ax=ax[0,int(indx/2)], data = data[col], palette="crest", color=rgb)
        ax[0,int(indx/2)].set_title(col)
    else:
        sns.boxplot(ax=ax[1, int((indx-1)/2)], data = data[col], palette="crest", color=rgb)
        ax[1, int((indx-1)/2)].set_title(col)
    indx += 1
plt.show()

# %% [markdown]
# Based on the figure above we can notice that all variables consist number of outliers. They might have a significant impact on the model efficiency.
# Firstly, it was noticed that for variables capital gains and capital losses all observations that have different values than zero are outliers.
# It is clearly visible on the box plot where the whole box actually is a straigh line around zero.
# Moreover, there is also a strange gap between some customers capital gains. There is a significant group of customers who gained exactly 99,999 euro which is not surrounded by any neighbours.
# Therefore, it was believed that these inputs might be errors.
#
# Based on these observations there was an idea to create new dataset which discretize capital loss and capital gain. However, further experiments revealed that badly impacts prediction capabilities. Ultimately, it was decided only to drop customers who gained 99,999 euro.

# %%
# Drop observations
indx = np.where(data["capital_gain"]==99999)
data = data.drop(index=indx[0])

# def discretize(x):
#     if x>0:
#         return "True"
#     else:
#         return "False"
    
# data["capital_gain"] = data["capital_gain"].apply(discretize)
# num_cols.remove("capital_gain")
# data["capital_loss"] = data["capital_loss"].apply(discretize)
# num_cols.remove("capital_loss")

# %% [markdown]
# ### Relationships between variables

# %% [markdown]
# #### Correlation

# %%
corr = data[num_cols].corr(method="spearman")
sns.heatmap(corr)
plt.show()

# %% [markdown]
# As we can see the correlation is really low, therefore there is no strong relationship between numerical variables.

# %% [markdown]
# #### Cramer's V

# %%
def cramers_V(var1,var2):
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

cramer_matrix = pd.DataFrame(np.zeros((len(cat_cols), len(cat_cols))), index=cat_cols, columns=cat_cols)
cat_memory = cat_cols.copy()
for row in cat_cols:
    for col in cat_memory:
        cramer_matrix.loc[row, col] = np.round(cramers_V(data[row], data[col]), 2)
        cramer_matrix.loc[col, row] = cramer_matrix.loc[row, col]
    cat_memory.remove(row)

sns.heatmap(cramer_matrix)
plt.title("Cramer's V heatmap")
plt.show()

# %% [markdown]
# There, was a slight expectation on my side that there might be relationship between variables, marital-status and relationship. However, on the heatmap we can notice that it is very weak. The strongest one is between relationship and sex. However, it is also not as siginificant. In short, the conclusion is clear. We don't have any variables with strong relationships.

# %% [markdown]
# ## Statistical analysis with depending variable

# %% [markdown]
# ### ANOVA analysis for numerical variables

# %%
anova_table = pd.DataFrame(np.zeros((1, len(num_cols))), 
                           ["label"], num_cols)

for num in num_cols:
    CategoryGroupLists = data.groupby("class")[num].apply(list)
    anova_results = f_oneway(*CategoryGroupLists)
    anova_table.loc["label", num] = np.round(anova_results.pvalue, 2)

print("\nTable below represents anova analysis between categorical and numerical variables:", anova_table, sep="\n\n")
# Out:
# Table below represents anova analysis between categorical and numerical variables:
#
#        age  capital_gain  capital_loss  hours_per_week
# label  0.0           0.0           0.0             0.0

# %% [markdown]
# As we can notice that for all numeric variables p-values are close to zero.
# Therefore, we can state that all of them might play crucial factor in predicting labels.

# %% [markdown]
# #### Chi-square analysis for categorical variables

# %%
chi2_table = pd.DataFrame(np.zeros((len(cat_cols), 1)), 
                            cat_cols, ["label"])
for col in cat_cols:
    crosstab = np.array(pd.crosstab(data[col],data["class"], rownames=None, colnames=None)) # Cross table building
    result = chi2_contingency(crosstab)
    chi2_table["label"][col] = result[1]

print("\nChi2 table", chi2_table, sep="\n")
# Out:
# Chi2 table
#                         label
# workclass       8.968457e-156
# education        0.000000e+00
# marital_status   0.000000e+00
# occupation       0.000000e+00
# relationship     0.000000e+00
# race             3.184270e-53
# sex              0.000000e+00

# %% [markdown]
# Based on the table we can conclude that all categorical variables are related to our dependent variable, as for each variable the p-value is close to 0.

# %% [markdown]
# ### Distribution of dependent variable

# %%
def discretize_func(x):
    if x == "<=50K":
        return 0 
    elif x == ">50K":
        return 1
    else:
        return x
        
data[dep_var] = data[dep_var].apply(discretize_func)
labels, counts = np.unique(data[dep_var], return_counts=True)
sns.barplot(y=counts/len(data), x=["<=50K", ">50K"])
plt.title(dep_var)
plt.show()

# %% [markdown]
# As we can see our depending variable is slightly imbalanced. Therefore, it was decided to use upsampling method in next steps to obtain more reliable results.

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Splitting Data

# %% [markdown]
# The first step was to divide data into training and testing data. The "train_test_split" method from sklearn was used.

# %%
ind_var = list(data.columns)
ind_var.remove("class")

train, test = train_test_split(data, test_size=0.2, shuffle=True, random_state=10)
X_train, X_test = train[ind_var], test[ind_var]
y_train, y_test = train["class"], test["class"]

# %% [markdown]
# ## Upsampling

# %% [markdown]
# The problem with imbalanced data is that model by assigning "<=50" label for every observation will obtain still very high accuracy. There are two sollutions for that problem, downsampling and upsampling. The first one randomly cuts observations which belongs to the bigger class. However, upsampling is a procedure which synthetically generates data points for smaller class. Ultimately, it was decided to go on with upsampling method as we do not loose information from our dataset. The SMOTE was the chosen algorithm.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# The first step was to preprocess data. To do that the ColumnTransformer was created. It consists preprocessing pipeline for categorical and numerical variables. For categorical ones the SimpleImputer with most frequent strategy was used. And to encode them the OneHotEncoder was used. However, numeric variables were scaled using StandardScaler.

# %%
unencodeded_categoric = list(X_train.dtypes[X_train.dtypes=="object"].index)
numeric = num_cols

numeric_transformer = imbpipeline(steps=[("scaler", StandardScaler())])
categoric_transformer = imbpipeline(steps=[
                                        ("imputer", SimpleImputer(strategy="most_frequent")),
                                        ("encoder", OneHotEncoder())
                                        ])

preprocessor = ColumnTransformer(transformers=[
                                            ("num_preprocessing", numeric_transformer, numeric),
                                            ("cat_preprocessing", categoric_transformer, unencodeded_categoric)
                                ])

# %% [markdown]
# ## Classifier Selection

# %% [markdown]
# In this project it was decided to compare five different algorithms and choose the best one for prediction. The following classifiers were taken into account:
# - K-Neighbors
# - Decision Tree
# - AdaBoost
# - Random Forest
# - Catboost
#
# The first two algorithms are rather simple ones and it was expected that they won't perform as well as the rest ones. However, I hoped that they would give some intuition regarding the data.
#
# All of these algorithms require a proper tunning. Therefore, a GridSearchCV method from sklearn was used. But before going into details about parameters used during grid search let's talk a little bit about models' parameters.
#
# ##### K-Neighbors
# For KNN method there were three different parameters which required tunning. The first one was n_neighbors. Here, it was decided to look at the range of odd numbers between 7 and 11. The second parameter was weights which has two different selection options, uniform and distance. The difference between these two is that uniform treats all neighbors equally, however distance assigns weights to neighbors by the inverse of their distance. The last one was metric. Here we have many selection options, however, it was decided to go on with euclidean/minkowski and cosine. Moreover, it was expected that cosine would be better as we have a lot of categorical data and by using OneHotEncoder the dimension has increased significantly.
#
# ##### Decision Tree
# For Decision Tree model there are plenty of parameters to take into account. Firstly, I was focused on criterion. It is responsible to measure the quality of the split. The selection was between Gini and Entropy. Moreover, based on theory we know that this algorithm tends to overfit as it grows. However, it includes some stopping criterias which aim to reduce that problem. These are max_depth, min_samples_split, min_samples_leaf and max_features. To visualize this issue it was decided to create a validation set and plot AUC scores which compares validation and training sets. The resulting figure was printed below. By looking at the first plot it can be concluded that while max_depth is around 10 the AUC scores between training and validation sets starts to diverge. Therefore, it was decided to include it in searching parameters.
#
# ##### AdaBoost
# AdaBoost is an example of Boosting algorithm. Here, there were only two parameters taken into account. The first one was n_estimators which represent the maximum number of estimators at which boosting is terminated. It was decided to choose from the list of [10, 50, 100, 500, 1000, 5000].
# The other parameter was the learning rate which is applied to classifier at each boosting iteration. There is also parameter called estimator from which the boosted ensemble is built. It was decided to go on with deafult one which is decision tree with one split.
#
# ##### Random Forest
# The aim of Random Forest is to fits number of decision tree classifiers on different data sub-samples. It uses averaging to improve the predictive accuracy and control over-fitting. Here we we have two parameters to tune. One of which is the criterion which is the same as in case of Decision Tree algorithm. The second one is n_estimators which consist number of trees in forest.
#
# ##### CatBoost
# CatBoost is an algorithm for gradient boosting on decision trees. There are different parameters. The first one determines the bootstrap type. The chosen selection was Bayesian and MVS. The second parameter was the l2_leaf_reg which is a coefficient at the L2 regularization for the cost function. The next one was learning rate. Based on the different applications it was decided to go on with rather low numbers. There is also a depth parameter which constitutes depth of the trees.

# %%
models = {"knn": KNeighborsClassifier(),
        "tree": DecisionTreeClassifier(random_state=2023),
        "ada": AdaBoostClassifier(random_state=2023),
        "random_forest": RandomForestClassifier(random_state=2023)}

params = {"knn": {"classifier__n_neighbors": [11,13,15],
                "classifier__weights": ["uniform", "distance"],
                "classifier__metric": ["minkowski", "cosine"]},
                
        "tree": {"classifier__criterion": ["gini", "entropy"],
                "classifier__max_depth": [6, 7, 8, 9, 10]},

        "ada": {"classifier__n_estimators": [10, 50, 100, 500, 1000, 5000],
                "classifier__learning_rate": [0.5, 0.75, 1]},

        "random_forest": {"classifier__n_estimators": [50, 100, 500],
                        "classifier__criterion": ["gini", "entropy"]}}
                        

def plot_tree_results(param_type, elements, ax):
    train_results = []
    test_results = []


    for element in elements:
        d = {param_type: element}
        dt = Pipeline(steps=[
                        ("preprocessing", preprocessor),
                        ("classifier", DecisionTreeClassifier(**d))], 
                verbose=False)
        dt.fit(X_train, y_train)
        train_pred = dt.predict(X_train)
        false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
        roc_auc = auc(false_positive_rate, true_positive_rate)
        # Add auc score to previous train results
        train_results.append(roc_auc)
        y_pred = dt.predict(X_test)
        false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
        roc_auc = auc(false_positive_rate, true_positive_rate)
        # Add auc score to previous test results
        test_results.append(roc_auc)

    line1, = ax.plot(elements, train_results, "b", label="Train AUC")
    line2, = ax.plot(elements, test_results, "r", label="Test AUC")
    ax.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
    ax.set_ylabel("AUC score")
    ax.set_xlabel(param_type)

fig, ax = plt.subplots(2,2)
elements = range(1,32)
plot_tree_results("max_depth", elements, ax[0,0])

min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True)
initial_parameters = {"max_depth": 10}
plot_tree_results("min_samples_split", min_samples_splits, ax[0,1])

min_samples_leafs = np.linspace(0.1, 0.5, 5, endpoint=True)
plot_tree_results("min_samples_leaf", min_samples_leafs, ax[1,0])

max_features = list(range(1, X_train.shape[1]))
plot_tree_results("max_features", max_features, ax[1,1])
plt.show()

# %% [markdown]
# To find optimal parameters for each model the GridSearchCV method was used. The roc auc metric was used as a scoring metric and three folds have been used. Also, the pipeline from imblearn library was used where following steps have been included, preprocessing, oversampling and classifying.

# %%
results = {}
for model in models.keys():
    print("\nGrid search for {}".format(model))
    pipe = imbpipeline(steps=[
                        ("preprocessing", preprocessor),
                        ('smote', SMOTE(random_state=2023)),
                        ("classifier", models[model])])

    random_search = GridSearchCV(estimator=pipe, 
                                param_grid=params[model],                                
                                refit=True, scoring="roc_auc", cv=3,
                                verbose=0, return_train_score=True)

    random_search.fit(X_train, y_train)
    print("ROC_AUC results: ", random_search.best_score_, "\nBest parameters:", "\n", random_search.best_params_)

    results[model] = random_search
    
best_models = {}
for key in models.keys():
    best_models[key] = results[key].best_estimator_
# Out:
# Grid search for knn
# ROC_AUC results:  0.8889076087467466
# Best parameters:
#  {'classifier__metric': 'minkowski', 'classifier__n_neighbors': 15, 'classifier__weights': 'uniform'}
#
# Grid search for tree
# ROC_AUC results:  0.8900983937894562
# Best parameters:
#  {'classifier__criterion': 'entropy', 'classifier__max_depth': 8}
#
# Grid search for ada
# ROC_AUC results:  0.9216054889759202
# Best parameters:
#  {'classifier__learning_rate': 1, 'classifier__n_estimators': 5000}
#
# Grid search for random_forest
# ROC_AUC results:  0.884193286041417
# Best parameters:
#  {'classifier__criterion': 'entropy', 'classifier__n_estimators': 500}

# %% [markdown]
# For CatBoost algorithm it was reccomended to use methods from its own library. Therefore, I needed to analyze it seperately. Firstly, it was decided to deal with NAs manually. Then, using transformed independent data and dependent one, the catboost.Pool object was created where all categorical variables were determined, so algorithm could deal with them without using OneHotEncoder. Moreover, to deal with imbalanced data instead of using SMOTE algorithm the scale_pos_weight parameter has been set to 3.

# %%
nas_count = X_train.isna().sum(axis = 0)
X_train_cat = X_train.copy()
for indx in nas_count[nas_count>0].index:
    md = mode(X_train_cat[indx])
    X_train_cat[indx] = X_train_cat[indx].fillna(md.mode[0])

nas_count = X_test.isna().sum(axis = 0)
X_test_cat = X_test.copy()
for indx in nas_count[nas_count>0].index:
    md = mode(X_test_cat[indx])
    X_test_cat[indx] = X_test_cat[indx].fillna(md.mode[0])

grid = {'bootstrap_type': ["Bayesian","MVS"], 
            'depth':[5, 7],
            'learning_rate':[0.1, 0.15],
            'l2_leaf_reg':[2, 3],
            'border_count':[5, 10],
            'bagging_temperature':[0.25, 0.75],
            'random_strength':[0.2, 0.8],
            'max_ctr_complexity':[3, 5]}


train_dataset = Pool(X_train_cat, y_train, cat_features=unencodeded_categoric)
test_dataset = Pool(X_test_cat, y_test, cat_features=unencodeded_categoric)

model = CatBoostClassifier(random_state=2023, iterations=100, eval_metric='AUC', scale_pos_weight=3)
result = model.grid_search(grid,train_dataset, plot=True, cv=3, partition_random_seed=2023)

best_models["catboost"] = result["params"]

# f = open("search_grid_results.pkl","wb")
# pickle.dump(best_models,f)
# f.close()
# Out:
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3021547799.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   md = mode(X_train_cat[indx])
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/scipy/stats/_stats_py.py:112: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3021547799.py:4: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   md = mode(X_train_cat[indx])
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3021547799.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   md = mode(X_test_cat[indx])
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/scipy/stats/_stats_py.py:112: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3021547799.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   md = mode(X_test_cat[indx])
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	test: 0.8927754	best: 0.8927754 (0)	total: 23.9ms	remaining: 2.37s
# 1:	test: 0.8946851	best: 0.8946851 (1)	total: 44.5ms	remaining: 2.18s
# 2:	test: 0.8988121	best: 0.8988121 (2)	total: 66.3ms	remaining: 2.14s
# 3:	test: 0.8991385	best: 0.8991385 (3)	total: 85.7ms	remaining: 2.06s
# 4:	test: 0.8990466	best: 0.8991385 (3)	total: 101ms	remaining: 1.91s
# 5:	test: 0.9025007	best: 0.9025007 (5)	total: 119ms	remaining: 1.86s
# 6:	test: 0.9040332	best: 0.9040332 (6)	total: 162ms	remaining: 2.15s
# 7:	test: 0.9048265	best: 0.9048265 (7)	total: 179ms	remaining: 2.06s
# 8:	test: 0.9056581	best: 0.9056581 (8)	total: 197ms	remaining: 1.99s
# 9:	test: 0.9057821	best: 0.9057821 (9)	total: 213ms	remaining: 1.92s
# 10:	test: 0.9064169	best: 0.9064169 (10)	total: 230ms	remaining: 1.86s
# 11:	test: 0.9075288	best: 0.9075288 (11)	total: 248ms	remaining: 1.82s
# 12:	test: 0.9088472	best: 0.9088472 (12)	total: 265ms	remaining: 1.77s
# 13:	test: 0.9097268	best: 0.9097268 (13)	total: 284ms	remaining: 1.74s
# 14:	test: 0.9100174	best: 0.9100174 (14)	total: 301ms	remaining: 1.71s
# 15:	test: 0.9107507	best: 0.9107507 (15)	total: 319ms	remaining: 1.67s
# 16:	test: 0.9112795	best: 0.9112795 (16)	total: 335ms	remaining: 1.63s
# 17:	test: 0.9115153	best: 0.9115153 (17)	total: 350ms	remaining: 1.59s
# 18:	test: 0.9118932	best: 0.9118932 (18)	total: 364ms	remaining: 1.55s
# 19:	test: 0.9125468	best: 0.9125468 (19)	total: 381ms	remaining: 1.52s
# 20:	test: 0.9127767	best: 0.9127767 (20)	total: 396ms	remaining: 1.49s
# 21:	test: 0.9130014	best: 0.9130014 (21)	total: 413ms	remaining: 1.46s
# 22:	test: 0.9132971	best: 0.9132971 (22)	total: 428ms	remaining: 1.43s
# 23:	test: 0.9136755	best: 0.9136755 (23)	total: 446ms	remaining: 1.41s
# 24:	test: 0.9137645	best: 0.9137645 (24)	total: 467ms	remaining: 1.4s
# 25:	test: 0.9141051	best: 0.9141051 (25)	total: 486ms	remaining: 1.38s
# 26:	test: 0.9145070	best: 0.9145070 (26)	total: 504ms	remaining: 1.36s
# 27:	test: 0.9150575	best: 0.9150575 (27)	total: 522ms	remaining: 1.34s
# 28:	test: 0.9152417	best: 0.9152417 (28)	total: 539ms	remaining: 1.32s
# 29:	test: 0.9154242	best: 0.9154242 (29)	total: 556ms	remaining: 1.3s
# 30:	test: 0.9156172	best: 0.9156172 (30)	total: 573ms	remaining: 1.27s
# 31:	test: 0.9156925	best: 0.9156925 (31)	total: 593ms	remaining: 1.26s
# 32:	test: 0.9158829	best: 0.9158829 (32)	total: 614ms	remaining: 1.25s
# 33:	test: 0.9159486	best: 0.9159486 (33)	total: 633ms	remaining: 1.23s
# 34:	test: 0.9163378	best: 0.9163378 (34)	total: 654ms	remaining: 1.21s
# 35:	test: 0.9164517	best: 0.9164517 (35)	total: 677ms	remaining: 1.2s
# 36:	test: 0.9165516	best: 0.9165516 (36)	total: 698ms	remaining: 1.19s
# 37:	test: 0.9166388	best: 0.9166388 (37)	total: 719ms	remaining: 1.17s
# 38:	test: 0.9166747	best: 0.9166747 (38)	total: 736ms	remaining: 1.15s
# 39:	test: 0.9167758	best: 0.9167758 (39)	total: 758ms	remaining: 1.14s
# 40:	test: 0.9169714	best: 0.9169714 (40)	total: 778ms	remaining: 1.12s
# 41:	test: 0.9171060	best: 0.9171060 (41)	total: 795ms	remaining: 1.1s
# 42:	test: 0.9171368	best: 0.9171368 (42)	total: 815ms	remaining: 1.08s
# 43:	test: 0.9169500	best: 0.9171368 (42)	total: 833ms	remaining: 1.06s
# 44:	test: 0.9169943	best: 0.9171368 (42)	total: 854ms	remaining: 1.04s
# 45:	test: 0.9171339	best: 0.9171368 (42)	total: 879ms	remaining: 1.03s
# 46:	test: 0.9172717	best: 0.9172717 (46)	total: 898ms	remaining: 1.01s
# 47:	test: 0.9172486	best: 0.9172717 (46)	total: 917ms	remaining: 994ms
# 48:	test: 0.9172370	best: 0.9172717 (46)	total: 936ms	remaining: 975ms
# 49:	test: 0.9172448	best: 0.9172717 (46)	total: 956ms	remaining: 956ms
# 50:	test: 0.9171829	best: 0.9172717 (46)	total: 977ms	remaining: 938ms
# 51:	test: 0.9171716	best: 0.9172717 (46)	total: 996ms	remaining: 920ms
# 52:	test: 0.9172682	best: 0.9172717 (46)	total: 1.01s	remaining: 901ms
# 53:	test: 0.9173148	best: 0.9173148 (53)	total: 1.03s	remaining: 879ms
# 54:	test: 0.9175047	best: 0.9175047 (54)	total: 1.05s	remaining: 858ms
# 55:	test: 0.9175427	best: 0.9175427 (55)	total: 1.07s	remaining: 839ms
# 56:	test: 0.9176032	best: 0.9176032 (56)	total: 1.09s	remaining: 820ms
# 57:	test: 0.9176083	best: 0.9176083 (57)	total: 1.1s	remaining: 800ms
# 58:	test: 0.9175755	best: 0.9176083 (57)	total: 1.12s	remaining: 780ms
# 59:	test: 0.9176136	best: 0.9176136 (59)	total: 1.14s	remaining: 758ms
# 60:	test: 0.9178438	best: 0.9178438 (60)	total: 1.15s	remaining: 738ms
# 61:	test: 0.9178001	best: 0.9178438 (60)	total: 1.17s	remaining: 718ms
# 62:	test: 0.9178372	best: 0.9178438 (60)	total: 1.19s	remaining: 697ms
# 63:	test: 0.9178836	best: 0.9178836 (63)	total: 1.2s	remaining: 677ms
# 64:	test: 0.9178891	best: 0.9178891 (64)	total: 1.22s	remaining: 657ms
# 65:	test: 0.9179465	best: 0.9179465 (65)	total: 1.24s	remaining: 636ms
# 66:	test: 0.9181321	best: 0.9181321 (66)	total: 1.25s	remaining: 616ms
# 67:	test: 0.9181239	best: 0.9181321 (66)	total: 1.27s	remaining: 596ms
# 68:	test: 0.9182495	best: 0.9182495 (68)	total: 1.28s	remaining: 576ms
# 69:	test: 0.9184431	best: 0.9184431 (69)	total: 1.3s	remaining: 557ms
# 70:	test: 0.9184231	best: 0.9184431 (69)	total: 1.32s	remaining: 539ms
# 71:	test: 0.9185003	best: 0.9185003 (71)	total: 1.34s	remaining: 520ms
# 72:	test: 0.9185821	best: 0.9185821 (72)	total: 1.35s	remaining: 500ms
# 73:	test: 0.9185858	best: 0.9185858 (73)	total: 1.37s	remaining: 480ms
# 74:	test: 0.9186289	best: 0.9186289 (74)	total: 1.38s	remaining: 461ms
# 75:	test: 0.9187588	best: 0.9187588 (75)	total: 1.4s	remaining: 442ms
# 76:	test: 0.9186671	best: 0.9187588 (75)	total: 1.41s	remaining: 423ms
# 77:	test: 0.9187459	best: 0.9187588 (75)	total: 1.43s	remaining: 403ms
# 78:	test: 0.9187310	best: 0.9187588 (75)	total: 1.44s	remaining: 384ms
# 79:	test: 0.9187749	best: 0.9187749 (79)	total: 1.46s	remaining: 365ms
# 80:	test: 0.9188368	best: 0.9188368 (80)	total: 1.48s	remaining: 346ms
# 81:	test: 0.9189091	best: 0.9189091 (81)	total: 1.49s	remaining: 327ms
# 82:	test: 0.9189936	best: 0.9189936 (82)	total: 1.51s	remaining: 309ms
# 83:	test: 0.9189517	best: 0.9189936 (82)	total: 1.53s	remaining: 291ms
# 84:	test: 0.9189685	best: 0.9189936 (82)	total: 1.54s	remaining: 272ms
# 85:	test: 0.9191163	best: 0.9191163 (85)	total: 1.56s	remaining: 254ms
# 86:	test: 0.9191278	best: 0.9191278 (86)	total: 1.58s	remaining: 236ms
# 87:	test: 0.9190926	best: 0.9191278 (86)	total: 1.59s	remaining: 218ms
# 88:	test: 0.9190910	best: 0.9191278 (86)	total: 1.61s	remaining: 199ms
# 89:	test: 0.9190996	best: 0.9191278 (86)	total: 1.63s	remaining: 181ms
# 90:	test: 0.9191135	best: 0.9191278 (86)	total: 1.64s	remaining: 162ms
# 91:	test: 0.9190839	best: 0.9191278 (86)	total: 1.65s	remaining: 144ms
# 92:	test: 0.9190798	best: 0.9191278 (86)	total: 1.67s	remaining: 125ms
# 93:	test: 0.9190804	best: 0.9191278 (86)	total: 1.68s	remaining: 107ms
# 94:	test: 0.9191723	best: 0.9191723 (94)	total: 1.7s	remaining: 89.3ms
# 95:	test: 0.9191923	best: 0.9191923 (95)	total: 1.71s	remaining: 71.3ms
# 96:	test: 0.9192507	best: 0.9192507 (96)	total: 1.73s	remaining: 53.5ms
# 97:	test: 0.9192881	best: 0.9192881 (97)	total: 1.75s	remaining: 35.7ms
# 98:	test: 0.9193032	best: 0.9193032 (98)	total: 1.76s	remaining: 17.8ms
# 99:	test: 0.9194588	best: 0.9194588 (99)	total: 1.78s	remaining: 0us
#
# bestTest = 0.9194587689
# bestIteration = 99
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.9194588	best: 0.9194588 (0)	total: 1.8s	remaining: 1m 53s
# 0:	test: 0.8927754	best: 0.8927754 (0)	total: 18.7ms	remaining: 1.85s
# 1:	test: 0.8953101	best: 0.8953101 (1)	total: 36.5ms	remaining: 1.79s
# 2:	test: 0.8973090	best: 0.8973090 (2)	total: 51.1ms	remaining: 1.65s
# 3:	test: 0.9030895	best: 0.9030895 (3)	total: 68ms	remaining: 1.63s
# 4:	test: 0.9048210	best: 0.9048210 (4)	total: 83.4ms	remaining: 1.58s
# 5:	test: 0.9060547	best: 0.9060547 (5)	total: 101ms	remaining: 1.58s
# 6:	test: 0.9079185	best: 0.9079185 (6)	total: 118ms	remaining: 1.56s
# 7:	test: 0.9083355	best: 0.9083355 (7)	total: 135ms	remaining: 1.56s
# 8:	test: 0.9085189	best: 0.9085189 (8)	total: 153ms	remaining: 1.55s
# 9:	test: 0.9100886	best: 0.9100886 (9)	total: 169ms	remaining: 1.52s
# 10:	test: 0.9105021	best: 0.9105021 (10)	total: 185ms	remaining: 1.5s
# 11:	test: 0.9114325	best: 0.9114325 (11)	total: 201ms	remaining: 1.47s
# 12:	test: 0.9119393	best: 0.9119393 (12)	total: 220ms	remaining: 1.47s
# 13:	test: 0.9125373	best: 0.9125373 (13)	total: 235ms	remaining: 1.45s
# 14:	test: 0.9132095	best: 0.9132095 (14)	total: 251ms	remaining: 1.42s
# 15:	test: 0.9137137	best: 0.9137137 (15)	total: 270ms	remaining: 1.42s
# 16:	test: 0.9140482	best: 0.9140482 (16)	total: 286ms	remaining: 1.4s
# 17:	test: 0.9139834	best: 0.9140482 (16)	total: 302ms	remaining: 1.38s
# 18:	test: 0.9140371	best: 0.9140482 (16)	total: 319ms	remaining: 1.36s
# 19:	test: 0.9145697	best: 0.9145697 (19)	total: 335ms	remaining: 1.34s
# 20:	test: 0.9149523	best: 0.9149523 (20)	total: 355ms	remaining: 1.33s
# 21:	test: 0.9151699	best: 0.9151699 (21)	total: 373ms	remaining: 1.32s
# 22:	test: 0.9149897	best: 0.9151699 (21)	total: 389ms	remaining: 1.3s
# 23:	test: 0.9151392	best: 0.9151699 (21)	total: 406ms	remaining: 1.28s
# 24:	test: 0.9152017	best: 0.9152017 (24)	total: 421ms	remaining: 1.26s
# 25:	test: 0.9153723	best: 0.9153723 (25)	total: 441ms	remaining: 1.25s
# 26:	test: 0.9154037	best: 0.9154037 (26)	total: 457ms	remaining: 1.24s
# 27:	test: 0.9155167	best: 0.9155167 (27)	total: 474ms	remaining: 1.22s
# 28:	test: 0.9157011	best: 0.9157011 (28)	total: 491ms	remaining: 1.2s
# 29:	test: 0.9157113	best: 0.9157113 (29)	total: 504ms	remaining: 1.18s
# 30:	test: 0.9163356	best: 0.9163356 (30)	total: 520ms	remaining: 1.16s
# 31:	test: 0.9163713	best: 0.9163713 (31)	total: 535ms	remaining: 1.14s
# 32:	test: 0.9163827	best: 0.9163827 (32)	total: 550ms	remaining: 1.11s
# 33:	test: 0.9164248	best: 0.9164248 (33)	total: 566ms	remaining: 1.1s
# 34:	test: 0.9165541	best: 0.9165541 (34)	total: 583ms	remaining: 1.08s
# 35:	test: 0.9165683	best: 0.9165683 (35)	total: 602ms	remaining: 1.07s
# 36:	test: 0.9168252	best: 0.9168252 (36)	total: 621ms	remaining: 1.06s
# 37:	test: 0.9169024	best: 0.9169024 (37)	total: 635ms	remaining: 1.03s
# 38:	test: 0.9170271	best: 0.9170271 (38)	total: 651ms	remaining: 1.02s
# 39:	test: 0.9170140	best: 0.9170271 (38)	total: 665ms	remaining: 998ms
# 40:	test: 0.9170363	best: 0.9170363 (40)	total: 684ms	remaining: 984ms
# 41:	test: 0.9172262	best: 0.9172262 (41)	total: 702ms	remaining: 969ms
# 42:	test: 0.9174183	best: 0.9174183 (42)	total: 720ms	remaining: 955ms
# 43:	test: 0.9176060	best: 0.9176060 (43)	total: 741ms	remaining: 943ms
# 44:	test: 0.9176919	best: 0.9176919 (44)	total: 760ms	remaining: 929ms
# 45:	test: 0.9176799	best: 0.9176919 (44)	total: 782ms	remaining: 918ms
# 46:	test: 0.9177020	best: 0.9177020 (46)	total: 802ms	remaining: 905ms
# 47:	test: 0.9176893	best: 0.9177020 (46)	total: 824ms	remaining: 893ms
# 48:	test: 0.9176685	best: 0.9177020 (46)	total: 845ms	remaining: 880ms
# 49:	test: 0.9176374	best: 0.9177020 (46)	total: 863ms	remaining: 863ms
# 50:	test: 0.9176474	best: 0.9177020 (46)	total: 883ms	remaining: 849ms
# 51:	test: 0.9176056	best: 0.9177020 (46)	total: 900ms	remaining: 831ms
# 52:	test: 0.9177414	best: 0.9177414 (52)	total: 917ms	remaining: 814ms
# 53:	test: 0.9177030	best: 0.9177414 (52)	total: 934ms	remaining: 795ms
# 54:	test: 0.9178161	best: 0.9178161 (54)	total: 954ms	remaining: 781ms
# 55:	test: 0.9178032	best: 0.9178161 (54)	total: 976ms	remaining: 766ms
# 56:	test: 0.9179678	best: 0.9179678 (56)	total: 994ms	remaining: 750ms
# 57:	test: 0.9180438	best: 0.9180438 (57)	total: 1.02s	remaining: 736ms
# 58:	test: 0.9182602	best: 0.9182602 (58)	total: 1.04s	remaining: 722ms
# 59:	test: 0.9183023	best: 0.9183023 (59)	total: 1.06s	remaining: 708ms
# 60:	test: 0.9183217	best: 0.9183217 (60)	total: 1.08s	remaining: 693ms
# 61:	test: 0.9183860	best: 0.9183860 (61)	total: 1.11s	remaining: 679ms
# 62:	test: 0.9183858	best: 0.9183860 (61)	total: 1.13s	remaining: 662ms
# 63:	test: 0.9183785	best: 0.9183860 (61)	total: 1.15s	remaining: 647ms
# 64:	test: 0.9183587	best: 0.9183860 (61)	total: 1.18s	remaining: 633ms
# 65:	test: 0.9184028	best: 0.9184028 (65)	total: 1.2s	remaining: 616ms
# 66:	test: 0.9185059	best: 0.9185059 (66)	total: 1.22s	remaining: 603ms
# 67:	test: 0.9185555	best: 0.9185555 (67)	total: 1.25s	remaining: 587ms
# 68:	test: 0.9184934	best: 0.9185555 (67)	total: 1.28s	remaining: 575ms
# 69:	test: 0.9185992	best: 0.9185992 (69)	total: 1.3s	remaining: 557ms
# 70:	test: 0.9187474	best: 0.9187474 (70)	total: 1.32s	remaining: 542ms
# 71:	test: 0.9187348	best: 0.9187474 (70)	total: 1.34s	remaining: 523ms
# 72:	test: 0.9187570	best: 0.9187570 (72)	total: 1.36s	remaining: 504ms
# 73:	test: 0.9187799	best: 0.9187799 (73)	total: 1.38s	remaining: 486ms
# 74:	test: 0.9186248	best: 0.9187799 (73)	total: 1.4s	remaining: 467ms
# 75:	test: 0.9185997	best: 0.9187799 (73)	total: 1.42s	remaining: 448ms
# 76:	test: 0.9184455	best: 0.9187799 (73)	total: 1.44s	remaining: 429ms
# 77:	test: 0.9184823	best: 0.9187799 (73)	total: 1.45s	remaining: 409ms
# 78:	test: 0.9185335	best: 0.9187799 (73)	total: 1.47s	remaining: 390ms
# 79:	test: 0.9185768	best: 0.9187799 (73)	total: 1.48s	remaining: 371ms
# 80:	test: 0.9185889	best: 0.9187799 (73)	total: 1.5s	remaining: 352ms
# 81:	test: 0.9186410	best: 0.9187799 (73)	total: 1.51s	remaining: 332ms
# 82:	test: 0.9186763	best: 0.9187799 (73)	total: 1.53s	remaining: 313ms
# 83:	test: 0.9186779	best: 0.9187799 (73)	total: 1.54s	remaining: 294ms
# 84:	test: 0.9187028	best: 0.9187799 (73)	total: 1.56s	remaining: 275ms
# 85:	test: 0.9186977	best: 0.9187799 (73)	total: 1.57s	remaining: 256ms
# 86:	test: 0.9187112	best: 0.9187799 (73)	total: 1.59s	remaining: 237ms
# 87:	test: 0.9187230	best: 0.9187799 (73)	total: 1.6s	remaining: 218ms
# 88:	test: 0.9187110	best: 0.9187799 (73)	total: 1.62s	remaining: 200ms
# 89:	test: 0.9188315	best: 0.9188315 (89)	total: 1.64s	remaining: 182ms
# 90:	test: 0.9188345	best: 0.9188345 (90)	total: 1.66s	remaining: 164ms
# 91:	test: 0.9188692	best: 0.9188692 (91)	total: 1.67s	remaining: 146ms
# 92:	test: 0.9188880	best: 0.9188880 (92)	total: 1.69s	remaining: 127ms
# 93:	test: 0.9188780	best: 0.9188880 (92)	total: 1.71s	remaining: 109ms
# 94:	test: 0.9189546	best: 0.9189546 (94)	total: 1.72s	remaining: 90.7ms
# 95:	test: 0.9190144	best: 0.9190144 (95)	total: 1.74s	remaining: 72.5ms
# 96:	test: 0.9189989	best: 0.9190144 (95)	total: 1.75s	remaining: 54.3ms
# 97:	test: 0.9190320	best: 0.9190320 (97)	total: 1.77s	remaining: 36.2ms
# 98:	test: 0.9190669	best: 0.9190669 (98)	total: 1.79s	remaining: 18.1ms
# 99:	test: 0.9189703	best: 0.9190669 (98)	total: 1.81s	remaining: 0us
#
# bestTest = 0.9190669128
# bestIteration = 98
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.9190669	best: 0.9194588 (0)	total: 3.61s	remaining: 1m 51s
# 0:	test: 0.8927366	best: 0.8927366 (0)	total: 18.4ms	remaining: 1.82s
# 1:	test: 0.8949681	best: 0.8949681 (1)	total: 36.3ms	remaining: 1.78s
# 2:	test: 0.8988670	best: 0.8988670 (2)	total: 51.8ms	remaining: 1.67s
# 3:	test: 0.8992406	best: 0.8992406 (3)	total: 67.8ms	remaining: 1.63s
# 4:	test: 0.8990458	best: 0.8992406 (3)	total: 82.1ms	remaining: 1.56s
# 5:	test: 0.9025675	best: 0.9025675 (5)	total: 97.6ms	remaining: 1.53s
# 6:	test: 0.9040283	best: 0.9040283 (6)	total: 114ms	remaining: 1.52s
# 7:	test: 0.9048474	best: 0.9048474 (7)	total: 130ms	remaining: 1.5s
# 8:	test: 0.9056053	best: 0.9056053 (8)	total: 148ms	remaining: 1.5s
# 9:	test: 0.9057243	best: 0.9057243 (9)	total: 165ms	remaining: 1.49s
# 10:	test: 0.9064294	best: 0.9064294 (10)	total: 181ms	remaining: 1.47s
# 11:	test: 0.9075376	best: 0.9075376 (11)	total: 201ms	remaining: 1.47s
# 12:	test: 0.9083000	best: 0.9083000 (12)	total: 217ms	remaining: 1.45s
# 13:	test: 0.9090601	best: 0.9090601 (13)	total: 236ms	remaining: 1.45s
# 14:	test: 0.9096568	best: 0.9096568 (14)	total: 252ms	remaining: 1.43s
# 15:	test: 0.9101761	best: 0.9101761 (15)	total: 271ms	remaining: 1.42s
# 16:	test: 0.9110000	best: 0.9110000 (16)	total: 289ms	remaining: 1.41s
# 17:	test: 0.9117437	best: 0.9117437 (17)	total: 304ms	remaining: 1.39s
# 18:	test: 0.9120185	best: 0.9120185 (18)	total: 324ms	remaining: 1.38s
# 19:	test: 0.9125225	best: 0.9125225 (19)	total: 339ms	remaining: 1.35s
# 20:	test: 0.9130566	best: 0.9130566 (20)	total: 357ms	remaining: 1.34s
# 21:	test: 0.9132521	best: 0.9132521 (21)	total: 374ms	remaining: 1.32s
# 22:	test: 0.9134226	best: 0.9134226 (22)	total: 389ms	remaining: 1.3s
# 23:	test: 0.9136327	best: 0.9136327 (23)	total: 408ms	remaining: 1.29s
# 24:	test: 0.9140280	best: 0.9140280 (24)	total: 426ms	remaining: 1.28s
# 25:	test: 0.9143349	best: 0.9143349 (25)	total: 447ms	remaining: 1.27s
# 26:	test: 0.9144619	best: 0.9144619 (26)	total: 465ms	remaining: 1.26s
# 27:	test: 0.9148955	best: 0.9148955 (27)	total: 480ms	remaining: 1.23s
# 28:	test: 0.9151840	best: 0.9151840 (28)	total: 496ms	remaining: 1.21s
# 29:	test: 0.9152579	best: 0.9152579 (29)	total: 513ms	remaining: 1.2s
# 30:	test: 0.9153300	best: 0.9153300 (30)	total: 529ms	remaining: 1.18s
# 31:	test: 0.9155119	best: 0.9155119 (31)	total: 546ms	remaining: 1.16s
# 32:	test: 0.9155550	best: 0.9155550 (32)	total: 562ms	remaining: 1.14s
# 33:	test: 0.9156877	best: 0.9156877 (33)	total: 578ms	remaining: 1.12s
# 34:	test: 0.9159121	best: 0.9159121 (34)	total: 598ms	remaining: 1.11s
# 35:	test: 0.9160529	best: 0.9160529 (35)	total: 617ms	remaining: 1.1s
# 36:	test: 0.9159521	best: 0.9160529 (35)	total: 632ms	remaining: 1.08s
# 37:	test: 0.9161451	best: 0.9161451 (37)	total: 650ms	remaining: 1.06s
# 38:	test: 0.9162703	best: 0.9162703 (38)	total: 667ms	remaining: 1.04s
# 39:	test: 0.9164633	best: 0.9164633 (39)	total: 686ms	remaining: 1.03s
# 40:	test: 0.9165288	best: 0.9165288 (40)	total: 703ms	remaining: 1.01s
# 41:	test: 0.9167986	best: 0.9167986 (41)	total: 721ms	remaining: 995ms
# 42:	test: 0.9169425	best: 0.9169425 (42)	total: 737ms	remaining: 977ms
# 43:	test: 0.9170426	best: 0.9170426 (43)	total: 753ms	remaining: 959ms
# 44:	test: 0.9171549	best: 0.9171549 (44)	total: 769ms	remaining: 940ms
# 45:	test: 0.9171954	best: 0.9171954 (45)	total: 787ms	remaining: 924ms
# 46:	test: 0.9172577	best: 0.9172577 (46)	total: 804ms	remaining: 907ms
# 47:	test: 0.9174674	best: 0.9174674 (47)	total: 822ms	remaining: 890ms
# 48:	test: 0.9174674	best: 0.9174674 (47)	total: 833ms	remaining: 867ms
# 49:	test: 0.9175139	best: 0.9175139 (49)	total: 848ms	remaining: 848ms
# 50:	test: 0.9174751	best: 0.9175139 (49)	total: 869ms	remaining: 835ms
# 51:	test: 0.9175539	best: 0.9175539 (51)	total: 885ms	remaining: 817ms
# 52:	test: 0.9175800	best: 0.9175800 (52)	total: 901ms	remaining: 799ms
# 53:	test: 0.9175851	best: 0.9175851 (53)	total: 917ms	remaining: 781ms
# 54:	test: 0.9176835	best: 0.9176835 (54)	total: 934ms	remaining: 764ms
# 55:	test: 0.9177051	best: 0.9177051 (55)	total: 949ms	remaining: 745ms
# 56:	test: 0.9177210	best: 0.9177210 (56)	total: 965ms	remaining: 728ms
# 57:	test: 0.9177370	best: 0.9177370 (57)	total: 981ms	remaining: 711ms
# 58:	test: 0.9178166	best: 0.9178166 (58)	total: 997ms	remaining: 693ms
# 59:	test: 0.9178358	best: 0.9178358 (59)	total: 1.01s	remaining: 675ms
# 60:	test: 0.9178545	best: 0.9178545 (60)	total: 1.03s	remaining: 656ms
# 61:	test: 0.9178782	best: 0.9178782 (61)	total: 1.04s	remaining: 639ms
# 62:	test: 0.9179746	best: 0.9179746 (62)	total: 1.06s	remaining: 622ms
# 63:	test: 0.9180219	best: 0.9180219 (63)	total: 1.08s	remaining: 605ms
# 64:	test: 0.9180397	best: 0.9180397 (64)	total: 1.09s	remaining: 589ms
# 65:	test: 0.9180577	best: 0.9180577 (65)	total: 1.11s	remaining: 573ms
# 66:	test: 0.9181391	best: 0.9181391 (66)	total: 1.13s	remaining: 556ms
# 67:	test: 0.9182494	best: 0.9182494 (67)	total: 1.14s	remaining: 539ms
# 68:	test: 0.9183366	best: 0.9183366 (68)	total: 1.16s	remaining: 521ms
# 69:	test: 0.9183360	best: 0.9183366 (68)	total: 1.17s	remaining: 503ms
# 70:	test: 0.9183378	best: 0.9183378 (70)	total: 1.19s	remaining: 485ms
# 71:	test: 0.9183184	best: 0.9183378 (70)	total: 1.2s	remaining: 468ms
# 72:	test: 0.9183820	best: 0.9183820 (72)	total: 1.23s	remaining: 453ms
# 73:	test: 0.9183696	best: 0.9183820 (72)	total: 1.25s	remaining: 439ms
# 74:	test: 0.9184876	best: 0.9184876 (74)	total: 1.27s	remaining: 424ms
# 75:	test: 0.9185581	best: 0.9185581 (75)	total: 1.29s	remaining: 408ms
# 76:	test: 0.9186069	best: 0.9186069 (76)	total: 1.31s	remaining: 391ms
# 77:	test: 0.9187688	best: 0.9187688 (77)	total: 1.33s	remaining: 375ms
# 78:	test: 0.9188300	best: 0.9188300 (78)	total: 1.35s	remaining: 358ms
# 79:	test: 0.9189225	best: 0.9189225 (79)	total: 1.36s	remaining: 341ms
# 80:	test: 0.9189415	best: 0.9189415 (80)	total: 1.38s	remaining: 324ms
# 81:	test: 0.9190596	best: 0.9190596 (81)	total: 1.4s	remaining: 307ms
# 82:	test: 0.9190594	best: 0.9190596 (81)	total: 1.42s	remaining: 290ms
# 83:	test: 0.9190839	best: 0.9190839 (83)	total: 1.44s	remaining: 273ms
# 84:	test: 0.9191692	best: 0.9191692 (84)	total: 1.46s	remaining: 257ms
# 85:	test: 0.9192823	best: 0.9192823 (85)	total: 1.48s	remaining: 240ms
# 86:	test: 0.9193463	best: 0.9193463 (86)	total: 1.49s	remaining: 223ms
# 87:	test: 0.9193548	best: 0.9193548 (87)	total: 1.51s	remaining: 206ms
# 88:	test: 0.9193361	best: 0.9193548 (87)	total: 1.53s	remaining: 189ms
# 89:	test: 0.9193625	best: 0.9193625 (89)	total: 1.54s	remaining: 172ms
# 90:	test: 0.9193317	best: 0.9193625 (89)	total: 1.56s	remaining: 155ms
# 91:	test: 0.9193315	best: 0.9193625 (89)	total: 1.58s	remaining: 137ms
# 92:	test: 0.9193925	best: 0.9193925 (92)	total: 1.59s	remaining: 120ms
# 93:	test: 0.9194319	best: 0.9194319 (93)	total: 1.61s	remaining: 103ms
# 94:	test: 0.9194244	best: 0.9194319 (93)	total: 1.63s	remaining: 85.8ms
# 95:	test: 0.9194491	best: 0.9194491 (95)	total: 1.65s	remaining: 68.8ms
# 96:	test: 0.9194750	best: 0.9194750 (96)	total: 1.67s	remaining: 51.7ms
# 97:	test: 0.9194734	best: 0.9194750 (96)	total: 1.68s	remaining: 34.4ms
# 98:	test: 0.9194421	best: 0.9194750 (96)	total: 1.7s	remaining: 17.2ms
# 99:	test: 0.9194697	best: 0.9194750 (96)	total: 1.72s	remaining: 0us
#
# bestTest = 0.9194750027
# bestIteration = 96
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.9194750	best: 0.9194750 (2)	total: 5.33s	remaining: 1m 48s
# 0:	test: 0.8927366	best: 0.8927366 (0)	total: 17ms	remaining: 1.69s
# 1:	test: 0.8954051	best: 0.8954051 (1)	total: 32.1ms	remaining: 1.57s
# 2:	test: 0.8974701	best: 0.8974701 (2)	total: 49.7ms	remaining: 1.61s
# 3:	test: 0.8986880	best: 0.8986880 (3)	total: 66.6ms	remaining: 1.6s
# 4:	test: 0.9026221	best: 0.9026221 (4)	total: 83.6ms	remaining: 1.59s
# 5:	test: 0.9058447	best: 0.9058447 (5)	total: 133ms	remaining: 2.09s
# 6:	test: 0.9066493	best: 0.9066493 (6)	total: 159ms	remaining: 2.12s
# 7:	test: 0.9076335	best: 0.9076335 (7)	total: 176ms	remaining: 2.02s
# 8:	test: 0.9089679	best: 0.9089679 (8)	total: 190ms	remaining: 1.92s
# 9:	test: 0.9103137	best: 0.9103137 (9)	total: 208ms	remaining: 1.87s
# 10:	test: 0.9110717	best: 0.9110717 (10)	total: 223ms	remaining: 1.81s
# 11:	test: 0.9113850	best: 0.9113850 (11)	total: 243ms	remaining: 1.78s
# 12:	test: 0.9120963	best: 0.9120963 (12)	total: 260ms	remaining: 1.74s
# 13:	test: 0.9122155	best: 0.9122155 (13)	total: 274ms	remaining: 1.68s
# 14:	test: 0.9129839	best: 0.9129839 (14)	total: 289ms	remaining: 1.64s
# 15:	test: 0.9132271	best: 0.9132271 (15)	total: 305ms	remaining: 1.6s
# 16:	test: 0.9131934	best: 0.9132271 (15)	total: 321ms	remaining: 1.57s
# 17:	test: 0.9135107	best: 0.9135107 (17)	total: 339ms	remaining: 1.54s
# 18:	test: 0.9139362	best: 0.9139362 (18)	total: 353ms	remaining: 1.51s
# 19:	test: 0.9142993	best: 0.9142993 (19)	total: 369ms	remaining: 1.48s
# 20:	test: 0.9145808	best: 0.9145808 (20)	total: 386ms	remaining: 1.45s
# 21:	test: 0.9148124	best: 0.9148124 (21)	total: 404ms	remaining: 1.43s
# 22:	test: 0.9150770	best: 0.9150770 (22)	total: 432ms	remaining: 1.45s
# 23:	test: 0.9150885	best: 0.9150885 (23)	total: 449ms	remaining: 1.42s
# 24:	test: 0.9152643	best: 0.9152643 (24)	total: 466ms	remaining: 1.4s
# 25:	test: 0.9154618	best: 0.9154618 (25)	total: 485ms	remaining: 1.38s
# 26:	test: 0.9156943	best: 0.9156943 (26)	total: 503ms	remaining: 1.36s
# 27:	test: 0.9157444	best: 0.9157444 (27)	total: 518ms	remaining: 1.33s
# 28:	test: 0.9157603	best: 0.9157603 (28)	total: 540ms	remaining: 1.32s
# 29:	test: 0.9160598	best: 0.9160598 (29)	total: 556ms	remaining: 1.3s
# 30:	test: 0.9160556	best: 0.9160598 (29)	total: 575ms	remaining: 1.28s
# 31:	test: 0.9162026	best: 0.9162026 (31)	total: 592ms	remaining: 1.26s
# 32:	test: 0.9165298	best: 0.9165298 (32)	total: 611ms	remaining: 1.24s
# 33:	test: 0.9168273	best: 0.9168273 (33)	total: 629ms	remaining: 1.22s
# 34:	test: 0.9168265	best: 0.9168273 (33)	total: 645ms	remaining: 1.2s
# 35:	test: 0.9167934	best: 0.9168273 (33)	total: 662ms	remaining: 1.18s
# 36:	test: 0.9168983	best: 0.9168983 (36)	total: 677ms	remaining: 1.15s
# 37:	test: 0.9169263	best: 0.9169263 (37)	total: 695ms	remaining: 1.13s
# 38:	test: 0.9169281	best: 0.9169281 (38)	total: 714ms	remaining: 1.12s
# 39:	test: 0.9170910	best: 0.9170910 (39)	total: 732ms	remaining: 1.1s
# 40:	test: 0.9170945	best: 0.9170945 (40)	total: 749ms	remaining: 1.08s
# 41:	test: 0.9170945	best: 0.9170945 (40)	total: 758ms	remaining: 1.05s
# 42:	test: 0.9172448	best: 0.9172448 (42)	total: 774ms	remaining: 1.03s
# 43:	test: 0.9172625	best: 0.9172625 (43)	total: 791ms	remaining: 1.01s
# 44:	test: 0.9174390	best: 0.9174390 (44)	total: 810ms	remaining: 990ms
# 45:	test: 0.9175140	best: 0.9175140 (45)	total: 828ms	remaining: 972ms
# 46:	test: 0.9174525	best: 0.9175140 (45)	total: 847ms	remaining: 955ms
# 47:	test: 0.9176042	best: 0.9176042 (47)	total: 864ms	remaining: 936ms
# 48:	test: 0.9176634	best: 0.9176634 (48)	total: 882ms	remaining: 918ms
# 49:	test: 0.9176803	best: 0.9176803 (49)	total: 898ms	remaining: 898ms
# 50:	test: 0.9176440	best: 0.9176803 (49)	total: 980ms	remaining: 942ms
# 51:	test: 0.9176131	best: 0.9176803 (49)	total: 1.01s	remaining: 932ms
# 52:	test: 0.9176268	best: 0.9176803 (49)	total: 1.04s	remaining: 921ms
# 53:	test: 0.9176114	best: 0.9176803 (49)	total: 1.07s	remaining: 911ms
# 54:	test: 0.9175146	best: 0.9176803 (49)	total: 1.09s	remaining: 891ms
# 55:	test: 0.9175195	best: 0.9176803 (49)	total: 1.1s	remaining: 867ms
# 56:	test: 0.9176696	best: 0.9176803 (49)	total: 1.12s	remaining: 846ms
# 57:	test: 0.9177016	best: 0.9177016 (57)	total: 1.14s	remaining: 825ms
# 58:	test: 0.9176686	best: 0.9177016 (57)	total: 1.16s	remaining: 803ms
# 59:	test: 0.9179469	best: 0.9179469 (59)	total: 1.18s	remaining: 784ms
# 60:	test: 0.9180059	best: 0.9180059 (60)	total: 1.19s	remaining: 763ms
# 61:	test: 0.9180100	best: 0.9180100 (61)	total: 1.21s	remaining: 741ms
# 62:	test: 0.9180259	best: 0.9180259 (62)	total: 1.22s	remaining: 718ms
# 63:	test: 0.9181452	best: 0.9181452 (63)	total: 1.24s	remaining: 696ms
# 64:	test: 0.9181390	best: 0.9181452 (63)	total: 1.26s	remaining: 677ms
# 65:	test: 0.9181672	best: 0.9181672 (65)	total: 1.27s	remaining: 657ms
# 66:	test: 0.9181658	best: 0.9181672 (65)	total: 1.29s	remaining: 637ms
# 67:	test: 0.9181768	best: 0.9181768 (67)	total: 1.31s	remaining: 617ms
# 68:	test: 0.9181848	best: 0.9181848 (68)	total: 1.33s	remaining: 596ms
# 69:	test: 0.9184335	best: 0.9184335 (69)	total: 1.34s	remaining: 576ms
# 70:	test: 0.9184688	best: 0.9184688 (70)	total: 1.36s	remaining: 555ms
# 71:	test: 0.9184723	best: 0.9184723 (71)	total: 1.38s	remaining: 535ms
# 72:	test: 0.9184707	best: 0.9184723 (71)	total: 1.39s	remaining: 515ms
# 73:	test: 0.9185476	best: 0.9185476 (73)	total: 1.41s	remaining: 495ms
# 74:	test: 0.9186369	best: 0.9186369 (74)	total: 1.43s	remaining: 476ms
# 75:	test: 0.9186497	best: 0.9186497 (75)	total: 1.45s	remaining: 459ms
# 76:	test: 0.9186481	best: 0.9186497 (75)	total: 1.48s	remaining: 441ms
# 77:	test: 0.9186638	best: 0.9186638 (77)	total: 1.49s	remaining: 421ms
# 78:	test: 0.9186295	best: 0.9186638 (77)	total: 1.51s	remaining: 401ms
# 79:	test: 0.9186798	best: 0.9186798 (79)	total: 1.53s	remaining: 382ms
# 80:	test: 0.9187974	best: 0.9187974 (80)	total: 1.55s	remaining: 363ms
# 81:	test: 0.9187482	best: 0.9187974 (80)	total: 1.57s	remaining: 345ms
# 82:	test: 0.9188560	best: 0.9188560 (82)	total: 1.59s	remaining: 325ms
# 83:	test: 0.9188300	best: 0.9188560 (82)	total: 1.6s	remaining: 306ms
# 84:	test: 0.9189042	best: 0.9189042 (84)	total: 1.63s	remaining: 287ms
# 85:	test: 0.9189383	best: 0.9189383 (85)	total: 1.64s	remaining: 268ms
# 86:	test: 0.9189861	best: 0.9189861 (86)	total: 1.66s	remaining: 249ms
# 87:	test: 0.9190449	best: 0.9190449 (87)	total: 1.68s	remaining: 230ms
# 88:	test: 0.9190630	best: 0.9190630 (88)	total: 1.7s	remaining: 211ms
# 89:	test: 0.9191080	best: 0.9191080 (89)	total: 1.72s	remaining: 191ms
# 90:	test: 0.9190224	best: 0.9191080 (89)	total: 1.74s	remaining: 172ms
# 91:	test: 0.9190477	best: 0.9191080 (89)	total: 1.75s	remaining: 152ms
# 92:	test: 0.9189473	best: 0.9191080 (89)	total: 1.77s	remaining: 133ms
# 93:	test: 0.9190820	best: 0.9191080 (89)	total: 1.79s	remaining: 114ms
# 94:	test: 0.9190667	best: 0.9191080 (89)	total: 1.81s	remaining: 95.1ms
# 95:	test: 0.9192417	best: 0.9192417 (95)	total: 1.82s	remaining: 76ms
# 96:	test: 0.9192595	best: 0.9192595 (96)	total: 1.84s	remaining: 57ms
# 97:	test: 0.9192164	best: 0.9192595 (96)	total: 1.86s	remaining: 37.9ms
# 98:	test: 0.9192058	best: 0.9192595 (96)	total: 1.87s	remaining: 18.9ms
# 99:	test: 0.9191994	best: 0.9192595 (96)	total: 1.89s	remaining: 0us
#
# bestTest = 0.9192594716
# bestIteration = 96
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.9192595	best: 0.9194750 (2)	total: 7.23s	remaining: 1m 48s
# 0:	test: 0.8927754	best: 0.8927754 (0)	total: 22.8ms	remaining: 2.25s
# 1:	test: 0.8946851	best: 0.8946851 (1)	total: 40.4ms	remaining: 1.98s
# 2:	test: 0.8988121	best: 0.8988121 (2)	total: 58.4ms	remaining: 1.89s
# 3:	test: 0.8991385	best: 0.8991385 (3)	total: 74.9ms	remaining: 1.8s
# 4:	test: 0.8990466	best: 0.8991385 (3)	total: 93.2ms	remaining: 1.77s
# 5:	test: 0.9025007	best: 0.9025007 (5)	total: 113ms	remaining: 1.77s
# 6:	test: 0.9040332	best: 0.9040332 (6)	total: 135ms	remaining: 1.8s
# 7:	test: 0.9048265	best: 0.9048265 (7)	total: 160ms	remaining: 1.83s
# 8:	test: 0.9056581	best: 0.9056581 (8)	total: 187ms	remaining: 1.89s
# 9:	test: 0.9057821	best: 0.9057821 (9)	total: 212ms	remaining: 1.91s
# 10:	test: 0.9064169	best: 0.9064169 (10)	total: 238ms	remaining: 1.93s
# 11:	test: 0.9075288	best: 0.9075288 (11)	total: 261ms	remaining: 1.92s
# 12:	test: 0.9088472	best: 0.9088472 (12)	total: 283ms	remaining: 1.89s
# 13:	test: 0.9097268	best: 0.9097268 (13)	total: 310ms	remaining: 1.91s
# 14:	test: 0.9100174	best: 0.9100174 (14)	total: 333ms	remaining: 1.89s
# 15:	test: 0.9107507	best: 0.9107507 (15)	total: 362ms	remaining: 1.9s
# 16:	test: 0.9112795	best: 0.9112795 (16)	total: 387ms	remaining: 1.89s
# 17:	test: 0.9115153	best: 0.9115153 (17)	total: 414ms	remaining: 1.89s
# 18:	test: 0.9118932	best: 0.9118932 (18)	total: 442ms	remaining: 1.89s
# 19:	test: 0.9125468	best: 0.9125468 (19)	total: 471ms	remaining: 1.88s
# 20:	test: 0.9127767	best: 0.9127767 (20)	total: 497ms	remaining: 1.87s
# 21:	test: 0.9130014	best: 0.9130014 (21)	total: 528ms	remaining: 1.87s
# 22:	test: 0.9132971	best: 0.9132971 (22)	total: 557ms	remaining: 1.86s
# 23:	test: 0.9136755	best: 0.9136755 (23)	total: 581ms	remaining: 1.84s
# 24:	test: 0.9137645	best: 0.9137645 (24)	total: 612ms	remaining: 1.83s
# 25:	test: 0.9141051	best: 0.9141051 (25)	total: 648ms	remaining: 1.84s
# 26:	test: 0.9145070	best: 0.9145070 (26)	total: 673ms	remaining: 1.82s
# 27:	test: 0.9150575	best: 0.9150575 (27)	total: 697ms	remaining: 1.79s
# 28:	test: 0.9152417	best: 0.9152417 (28)	total: 725ms	remaining: 1.77s
# 29:	test: 0.9154242	best: 0.9154242 (29)	total: 754ms	remaining: 1.76s
# 30:	test: 0.9156172	best: 0.9156172 (30)	total: 787ms	remaining: 1.75s
# 31:	test: 0.9156925	best: 0.9156925 (31)	total: 817ms	remaining: 1.74s
# 32:	test: 0.9158829	best: 0.9158829 (32)	total: 843ms	remaining: 1.71s
# 33:	test: 0.9159486	best: 0.9159486 (33)	total: 867ms	remaining: 1.68s
# 34:	test: 0.9163378	best: 0.9163378 (34)	total: 893ms	remaining: 1.66s
# 35:	test: 0.9164517	best: 0.9164517 (35)	total: 914ms	remaining: 1.63s
# 36:	test: 0.9165516	best: 0.9165516 (36)	total: 937ms	remaining: 1.59s
# 37:	test: 0.9166388	best: 0.9166388 (37)	total: 960ms	remaining: 1.57s
# 38:	test: 0.9166747	best: 0.9166747 (38)	total: 981ms	remaining: 1.53s
# 39:	test: 0.9167762	best: 0.9167762 (39)	total: 1s	remaining: 1.51s
# 40:	test: 0.9169549	best: 0.9169549 (40)	total: 1.02s	remaining: 1.47s
# 41:	test: 0.9171018	best: 0.9171018 (41)	total: 1.05s	remaining: 1.45s
# 42:	test: 0.9170687	best: 0.9171018 (41)	total: 1.07s	remaining: 1.42s
# 43:	test: 0.9170928	best: 0.9171018 (41)	total: 1.09s	remaining: 1.39s
# 44:	test: 0.9171833	best: 0.9171833 (44)	total: 1.11s	remaining: 1.36s
# 45:	test: 0.9172094	best: 0.9172094 (45)	total: 1.14s	remaining: 1.34s
# 46:	test: 0.9173366	best: 0.9173366 (46)	total: 1.16s	remaining: 1.31s
# 47:	test: 0.9174365	best: 0.9174365 (47)	total: 1.19s	remaining: 1.28s
# 48:	test: 0.9176049	best: 0.9176049 (48)	total: 1.21s	remaining: 1.25s
# 49:	test: 0.9176106	best: 0.9176106 (49)	total: 1.23s	remaining: 1.23s
# 50:	test: 0.9176598	best: 0.9176598 (50)	total: 1.25s	remaining: 1.2s
# 51:	test: 0.9179269	best: 0.9179269 (51)	total: 1.28s	remaining: 1.18s
# 52:	test: 0.9179197	best: 0.9179269 (51)	total: 1.3s	remaining: 1.15s
# 53:	test: 0.9180051	best: 0.9180051 (53)	total: 1.32s	remaining: 1.13s
# 54:	test: 0.9182454	best: 0.9182454 (54)	total: 1.34s	remaining: 1.1s
# 55:	test: 0.9183345	best: 0.9183345 (55)	total: 1.37s	remaining: 1.07s
# 56:	test: 0.9183287	best: 0.9183345 (55)	total: 1.39s	remaining: 1.05s
# 57:	test: 0.9183869	best: 0.9183869 (57)	total: 1.42s	remaining: 1.02s
# 58:	test: 0.9183961	best: 0.9183961 (58)	total: 1.44s	remaining: 999ms
# 59:	test: 0.9184662	best: 0.9184662 (59)	total: 1.46s	remaining: 972ms
# 60:	test: 0.9184606	best: 0.9184662 (59)	total: 1.48s	remaining: 948ms
# 61:	test: 0.9185213	best: 0.9185213 (61)	total: 1.51s	remaining: 924ms
# 62:	test: 0.9185150	best: 0.9185213 (61)	total: 1.53s	remaining: 898ms
# 63:	test: 0.9186087	best: 0.9186087 (63)	total: 1.55s	remaining: 874ms
# 64:	test: 0.9186459	best: 0.9186459 (64)	total: 1.57s	remaining: 848ms
# 65:	test: 0.9186793	best: 0.9186793 (65)	total: 1.6s	remaining: 823ms
# 66:	test: 0.9187361	best: 0.9187361 (66)	total: 1.62s	remaining: 798ms
# 67:	test: 0.9188501	best: 0.9188501 (67)	total: 1.64s	remaining: 772ms
# 68:	test: 0.9188913	best: 0.9188913 (68)	total: 1.66s	remaining: 748ms
# 69:	test: 0.9188917	best: 0.9188917 (69)	total: 1.68s	remaining: 722ms
# 70:	test: 0.9188333	best: 0.9188917 (69)	total: 1.71s	remaining: 698ms
# 71:	test: 0.9188558	best: 0.9188917 (69)	total: 1.73s	remaining: 674ms
# 72:	test: 0.9187953	best: 0.9188917 (69)	total: 1.76s	remaining: 650ms
# 73:	test: 0.9189691	best: 0.9189691 (73)	total: 1.81s	remaining: 635ms
# 74:	test: 0.9189926	best: 0.9189926 (74)	total: 1.83s	remaining: 612ms
# 75:	test: 0.9190214	best: 0.9190214 (75)	total: 1.86s	remaining: 587ms
# 76:	test: 0.9190843	best: 0.9190843 (76)	total: 1.88s	remaining: 562ms
# 77:	test: 0.9191760	best: 0.9191760 (77)	total: 1.91s	remaining: 537ms
# 78:	test: 0.9191898	best: 0.9191898 (78)	total: 1.93s	remaining: 514ms
# 79:	test: 0.9192825	best: 0.9192825 (79)	total: 1.95s	remaining: 488ms
# 80:	test: 0.9193505	best: 0.9193505 (80)	total: 1.97s	remaining: 463ms
# 81:	test: 0.9193971	best: 0.9193971 (81)	total: 1.99s	remaining: 438ms
# 82:	test: 0.9194373	best: 0.9194373 (82)	total: 2.02s	remaining: 413ms
# 83:	test: 0.9194504	best: 0.9194504 (83)	total: 2.04s	remaining: 388ms
# 84:	test: 0.9194520	best: 0.9194520 (84)	total: 2.06s	remaining: 363ms
# 85:	test: 0.9195061	best: 0.9195061 (85)	total: 2.08s	remaining: 338ms
# 86:	test: 0.9195523	best: 0.9195523 (86)	total: 2.1s	remaining: 315ms
# 87:	test: 0.9195725	best: 0.9195725 (87)	total: 2.14s	remaining: 292ms
# 88:	test: 0.9196268	best: 0.9196268 (88)	total: 2.18s	remaining: 270ms
# 89:	test: 0.9196419	best: 0.9196419 (89)	total: 2.21s	remaining: 246ms
# 90:	test: 0.9196352	best: 0.9196419 (89)	total: 2.24s	remaining: 221ms
# 91:	test: 0.9197500	best: 0.9197500 (91)	total: 2.26s	remaining: 197ms
# 92:	test: 0.9197718	best: 0.9197718 (92)	total: 2.29s	remaining: 172ms
# 93:	test: 0.9197710	best: 0.9197718 (92)	total: 2.31s	remaining: 147ms
# 94:	test: 0.9197661	best: 0.9197718 (92)	total: 2.34s	remaining: 123ms
# 95:	test: 0.9197638	best: 0.9197718 (92)	total: 2.36s	remaining: 98.5ms
# 96:	test: 0.9199527	best: 0.9199527 (96)	total: 2.39s	remaining: 73.8ms
# 97:	test: 0.9199521	best: 0.9199527 (96)	total: 2.41s	remaining: 49.1ms
# 98:	test: 0.9199417	best: 0.9199527 (96)	total: 2.43s	remaining: 24.6ms
# 99:	test: 0.9199789	best: 0.9199789 (99)	total: 2.46s	remaining: 0us
#
# bestTest = 0.9199788614
# bestIteration = 99
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.9199789	best: 0.9199789 (4)	total: 9.7s	remaining: 1m 54s
# 0:	test: 0.8927754	best: 0.8927754 (0)	total: 26.1ms	remaining: 2.58s
# 1:	test: 0.8953101	best: 0.8953101 (1)	total: 49.9ms	remaining: 2.44s
# 2:	test: 0.8973090	best: 0.8973090 (2)	total: 73ms	remaining: 2.36s
# 3:	test: 0.9030895	best: 0.9030895 (3)	total: 96.7ms	remaining: 2.32s
# 4:	test: 0.9048210	best: 0.9048210 (4)	total: 120ms	remaining: 2.28s
# 5:	test: 0.9060547	best: 0.9060547 (5)	total: 145ms	remaining: 2.27s
# 6:	test: 0.9079185	best: 0.9079185 (6)	total: 162ms	remaining: 2.15s
# 7:	test: 0.9083355	best: 0.9083355 (7)	total: 180ms	remaining: 2.07s
# 8:	test: 0.9085189	best: 0.9085189 (8)	total: 197ms	remaining: 1.99s
# 9:	test: 0.9100886	best: 0.9100886 (9)	total: 215ms	remaining: 1.94s
# 10:	test: 0.9105021	best: 0.9105021 (10)	total: 232ms	remaining: 1.88s
# 11:	test: 0.9114325	best: 0.9114325 (11)	total: 252ms	remaining: 1.85s
# 12:	test: 0.9119393	best: 0.9119393 (12)	total: 272ms	remaining: 1.82s
# 13:	test: 0.9125373	best: 0.9125373 (13)	total: 290ms	remaining: 1.78s
# 14:	test: 0.9132095	best: 0.9132095 (14)	total: 306ms	remaining: 1.74s
# 15:	test: 0.9137137	best: 0.9137137 (15)	total: 323ms	remaining: 1.7s
# 16:	test: 0.9140482	best: 0.9140482 (16)	total: 346ms	remaining: 1.69s
# 17:	test: 0.9139834	best: 0.9140482 (16)	total: 365ms	remaining: 1.66s
# 18:	test: 0.9140371	best: 0.9140482 (16)	total: 383ms	remaining: 1.63s
# 19:	test: 0.9145697	best: 0.9145697 (19)	total: 400ms	remaining: 1.6s
# 20:	test: 0.9149523	best: 0.9149523 (20)	total: 418ms	remaining: 1.57s
# 21:	test: 0.9151699	best: 0.9151699 (21)	total: 437ms	remaining: 1.55s
# 22:	test: 0.9149897	best: 0.9151699 (21)	total: 455ms	remaining: 1.52s
# 23:	test: 0.9151392	best: 0.9151699 (21)	total: 473ms	remaining: 1.5s
# 24:	test: 0.9152017	best: 0.9152017 (24)	total: 491ms	remaining: 1.47s
# 25:	test: 0.9153723	best: 0.9153723 (25)	total: 510ms	remaining: 1.45s
# 26:	test: 0.9154037	best: 0.9154037 (26)	total: 529ms	remaining: 1.43s
# 27:	test: 0.9155167	best: 0.9155167 (27)	total: 548ms	remaining: 1.41s
# 28:	test: 0.9157011	best: 0.9157011 (28)	total: 570ms	remaining: 1.4s
# 29:	test: 0.9157113	best: 0.9157113 (29)	total: 587ms	remaining: 1.37s
# 30:	test: 0.9163356	best: 0.9163356 (30)	total: 607ms	remaining: 1.35s
# 31:	test: 0.9163713	best: 0.9163713 (31)	total: 625ms	remaining: 1.33s
# 32:	test: 0.9163827	best: 0.9163827 (32)	total: 641ms	remaining: 1.3s
# 33:	test: 0.9164248	best: 0.9164248 (33)	total: 657ms	remaining: 1.27s
# 34:	test: 0.9165541	best: 0.9165541 (34)	total: 676ms	remaining: 1.25s
# 35:	test: 0.9165683	best: 0.9165683 (35)	total: 691ms	remaining: 1.23s
# 36:	test: 0.9168252	best: 0.9168252 (36)	total: 711ms	remaining: 1.21s
# 37:	test: 0.9169024	best: 0.9169024 (37)	total: 727ms	remaining: 1.19s
# 38:	test: 0.9170271	best: 0.9170271 (38)	total: 748ms	remaining: 1.17s
# 39:	test: 0.9170140	best: 0.9170271 (38)	total: 765ms	remaining: 1.15s
# 40:	test: 0.9170363	best: 0.9170363 (40)	total: 782ms	remaining: 1.13s
# 41:	test: 0.9172262	best: 0.9172262 (41)	total: 798ms	remaining: 1.1s
# 42:	test: 0.9174183	best: 0.9174183 (42)	total: 816ms	remaining: 1.08s
# 43:	test: 0.9176060	best: 0.9176060 (43)	total: 835ms	remaining: 1.06s
# 44:	test: 0.9176919	best: 0.9176919 (44)	total: 853ms	remaining: 1.04s
# 45:	test: 0.9176799	best: 0.9176919 (44)	total: 873ms	remaining: 1.02s
# 46:	test: 0.9177020	best: 0.9177020 (46)	total: 893ms	remaining: 1.01s
# 47:	test: 0.9176893	best: 0.9177020 (46)	total: 916ms	remaining: 992ms
# 48:	test: 0.9176685	best: 0.9177020 (46)	total: 941ms	remaining: 979ms
# 49:	test: 0.9176374	best: 0.9177020 (46)	total: 965ms	remaining: 965ms
# 50:	test: 0.9176474	best: 0.9177020 (46)	total: 994ms	remaining: 955ms
# 51:	test: 0.9176056	best: 0.9177020 (46)	total: 1.01s	remaining: 938ms
# 52:	test: 0.9177414	best: 0.9177414 (52)	total: 1.04s	remaining: 924ms
# 53:	test: 0.9177030	best: 0.9177414 (52)	total: 1.07s	remaining: 909ms
# 54:	test: 0.9178161	best: 0.9178161 (54)	total: 1.09s	remaining: 889ms
# 55:	test: 0.9178032	best: 0.9178161 (54)	total: 1.1s	remaining: 868ms
# 56:	test: 0.9179678	best: 0.9179678 (56)	total: 1.12s	remaining: 848ms
# 57:	test: 0.9180438	best: 0.9180438 (57)	total: 1.14s	remaining: 825ms
# 58:	test: 0.9182602	best: 0.9182602 (58)	total: 1.16s	remaining: 804ms
# 59:	test: 0.9183023	best: 0.9183023 (59)	total: 1.17s	remaining: 783ms
# 60:	test: 0.9183217	best: 0.9183217 (60)	total: 1.19s	remaining: 764ms
# 61:	test: 0.9183860	best: 0.9183860 (61)	total: 1.21s	remaining: 743ms
# 62:	test: 0.9183858	best: 0.9183860 (61)	total: 1.23s	remaining: 722ms
# 63:	test: 0.9183785	best: 0.9183860 (61)	total: 1.25s	remaining: 702ms
# 64:	test: 0.9184769	best: 0.9184769 (64)	total: 1.27s	remaining: 684ms
# 65:	test: 0.9184712	best: 0.9184769 (64)	total: 1.29s	remaining: 663ms
# 66:	test: 0.9184822	best: 0.9184822 (66)	total: 1.3s	remaining: 642ms
# 67:	test: 0.9186578	best: 0.9186578 (67)	total: 1.32s	remaining: 622ms
# 68:	test: 0.9186843	best: 0.9186843 (68)	total: 1.34s	remaining: 601ms
# 69:	test: 0.9186843	best: 0.9186843 (68)	total: 1.35s	remaining: 578ms
# 70:	test: 0.9188069	best: 0.9188069 (70)	total: 1.37s	remaining: 559ms
# 71:	test: 0.9189659	best: 0.9189659 (71)	total: 1.39s	remaining: 539ms
# 72:	test: 0.9189659	best: 0.9189659 (71)	total: 1.4s	remaining: 519ms
# 73:	test: 0.9189639	best: 0.9189659 (71)	total: 1.42s	remaining: 499ms
# 74:	test: 0.9189694	best: 0.9189694 (74)	total: 1.44s	remaining: 479ms
# 75:	test: 0.9189112	best: 0.9189694 (74)	total: 1.45s	remaining: 459ms
# 76:	test: 0.9189455	best: 0.9189694 (74)	total: 1.47s	remaining: 439ms
# 77:	test: 0.9189486	best: 0.9189694 (74)	total: 1.49s	remaining: 420ms
# 78:	test: 0.9189508	best: 0.9189694 (74)	total: 1.5s	remaining: 400ms
# 79:	test: 0.9189947	best: 0.9189947 (79)	total: 1.52s	remaining: 381ms
# 80:	test: 0.9189598	best: 0.9189947 (79)	total: 1.54s	remaining: 362ms
# 81:	test: 0.9189412	best: 0.9189947 (79)	total: 1.56s	remaining: 343ms
# 82:	test: 0.9189545	best: 0.9189947 (79)	total: 1.58s	remaining: 324ms
# 83:	test: 0.9188679	best: 0.9189947 (79)	total: 1.6s	remaining: 305ms
# 84:	test: 0.9188291	best: 0.9189947 (79)	total: 1.62s	remaining: 286ms
# 85:	test: 0.9188308	best: 0.9189947 (79)	total: 1.64s	remaining: 267ms
# 86:	test: 0.9188851	best: 0.9189947 (79)	total: 1.66s	remaining: 248ms
# 87:	test: 0.9188932	best: 0.9189947 (79)	total: 1.68s	remaining: 229ms
# 88:	test: 0.9188834	best: 0.9189947 (79)	total: 1.7s	remaining: 210ms
# 89:	test: 0.9189173	best: 0.9189947 (79)	total: 1.73s	remaining: 192ms
# 90:	test: 0.9189110	best: 0.9189947 (79)	total: 1.75s	remaining: 173ms
# 91:	test: 0.9189513	best: 0.9189947 (79)	total: 1.77s	remaining: 154ms
# 92:	test: 0.9190036	best: 0.9190036 (92)	total: 1.79s	remaining: 135ms
# 93:	test: 0.9191772	best: 0.9191772 (93)	total: 1.83s	remaining: 117ms
# 94:	test: 0.9192464	best: 0.9192464 (94)	total: 1.85s	remaining: 97.6ms
# 95:	test: 0.9193089	best: 0.9193089 (95)	total: 1.88s	remaining: 78.3ms
# 96:	test: 0.9193117	best: 0.9193117 (96)	total: 1.9s	remaining: 58.9ms
# 97:	test: 0.9192809	best: 0.9193117 (96)	total: 1.93s	remaining: 39.4ms
# 98:	test: 0.9192819	best: 0.9193117 (96)	total: 1.96s	remaining: 19.8ms
# 99:	test: 0.9192664	best: 0.9193117 (96)	total: 1.99s	remaining: 0us
#
# bestTest = 0.9193117463
# bestIteration = 96
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.9193117	best: 0.9199789 (4)	total: 11.7s	remaining: 1m 53s
# 0:	test: 0.8927366	best: 0.8927366 (0)	total: 30ms	remaining: 2.97s
# 1:	test: 0.8949681	best: 0.8949681 (1)	total: 67.9ms	remaining: 3.33s
# 2:	test: 0.8988670	best: 0.8988670 (2)	total: 94.8ms	remaining: 3.06s
# 3:	test: 0.8992406	best: 0.8992406 (3)	total: 123ms	remaining: 2.95s
# 4:	test: 0.8990458	best: 0.8992406 (3)	total: 154ms	remaining: 2.93s
# 5:	test: 0.9025675	best: 0.9025675 (5)	total: 182ms	remaining: 2.85s
# 6:	test: 0.9040283	best: 0.9040283 (6)	total: 205ms	remaining: 2.72s
# 7:	test: 0.9048474	best: 0.9048474 (7)	total: 235ms	remaining: 2.7s
# 8:	test: 0.9056053	best: 0.9056053 (8)	total: 268ms	remaining: 2.71s
# 9:	test: 0.9057243	best: 0.9057243 (9)	total: 316ms	remaining: 2.84s
# 10:	test: 0.9064294	best: 0.9064294 (10)	total: 340ms	remaining: 2.75s
# 11:	test: 0.9075376	best: 0.9075376 (11)	total: 365ms	remaining: 2.68s
# 12:	test: 0.9083000	best: 0.9083000 (12)	total: 393ms	remaining: 2.63s
# 13:	test: 0.9090601	best: 0.9090601 (13)	total: 415ms	remaining: 2.55s
# 14:	test: 0.9096568	best: 0.9096568 (14)	total: 436ms	remaining: 2.47s
# 15:	test: 0.9101761	best: 0.9101761 (15)	total: 462ms	remaining: 2.42s
# 16:	test: 0.9110000	best: 0.9110000 (16)	total: 484ms	remaining: 2.36s
# 17:	test: 0.9117437	best: 0.9117437 (17)	total: 505ms	remaining: 2.3s
# 18:	test: 0.9120185	best: 0.9120185 (18)	total: 530ms	remaining: 2.26s
# 19:	test: 0.9125225	best: 0.9125225 (19)	total: 552ms	remaining: 2.21s
# 20:	test: 0.9130566	best: 0.9130566 (20)	total: 576ms	remaining: 2.17s
# 21:	test: 0.9132521	best: 0.9132521 (21)	total: 599ms	remaining: 2.12s
# 22:	test: 0.9134226	best: 0.9134226 (22)	total: 619ms	remaining: 2.07s
# 23:	test: 0.9136327	best: 0.9136327 (23)	total: 642ms	remaining: 2.03s
# ...
# 77:	test: 0.9251395	best: 0.9251691 (74)	total: 1.49s	remaining: 419ms
# 78:	test: 0.9251466	best: 0.9251691 (74)	total: 1.5s	remaining: 400ms
# 79:	test: 0.9253558	best: 0.9253558 (79)	total: 1.52s	remaining: 380ms
# 80:	test: 0.9252551	best: 0.9253558 (79)	total: 1.54s	remaining: 361ms
# 81:	test: 0.9252135	best: 0.9253558 (79)	total: 1.56s	remaining: 342ms
# 82:	test: 0.9252334	best: 0.9253558 (79)	total: 1.58s	remaining: 323ms
# 83:	test: 0.9255034	best: 0.9255034 (83)	total: 1.6s	remaining: 306ms
# 84:	test: 0.9254975	best: 0.9255034 (83)	total: 1.63s	remaining: 288ms
# 85:	test: 0.9254975	best: 0.9255034 (83)	total: 1.65s	remaining: 269ms
# 86:	test: 0.9255058	best: 0.9255058 (86)	total: 1.68s	remaining: 251ms
# 87:	test: 0.9255058	best: 0.9255058 (86)	total: 1.7s	remaining: 231ms
# 88:	test: 0.9255243	best: 0.9255243 (88)	total: 1.71s	remaining: 212ms
# 89:	test: 0.9254093	best: 0.9255243 (88)	total: 1.73s	remaining: 192ms
# 90:	test: 0.9255040	best: 0.9255243 (88)	total: 1.75s	remaining: 173ms
# 91:	test: 0.9255893	best: 0.9255893 (91)	total: 1.76s	remaining: 153ms
# 92:	test: 0.9256391	best: 0.9256391 (92)	total: 1.78s	remaining: 134ms
# 93:	test: 0.9253895	best: 0.9256391 (92)	total: 1.8s	remaining: 115ms
# 94:	test: 0.9256027	best: 0.9256391 (92)	total: 1.82s	remaining: 95.8ms
# 95:	test: 0.9256032	best: 0.9256391 (92)	total: 1.84s	remaining: 76.7ms
# 96:	test: 0.9256072	best: 0.9256391 (92)	total: 1.86s	remaining: 57.5ms
# 97:	test: 0.9255975	best: 0.9256391 (92)	total: 1.88s	remaining: 38.3ms
# 98:	test: 0.9256340	best: 0.9256391 (92)	total: 1.89s	remaining: 19.1ms
# 99:	test: 0.9256393	best: 0.9256393 (99)	total: 1.91s	remaining: 0us
#
# bestTest = 0.9256393278
# bestIteration = 99
#
# Training on fold [1/3]
# 0:	test: 0.8883382	best: 0.8883382 (0)	total: 18.6ms	remaining: 1.84s
# 1:	test: 0.8942440	best: 0.8942440 (1)	total: 38.3ms	remaining: 1.88s
# 2:	test: 0.8950089	best: 0.8950089 (2)	total: 55.3ms	remaining: 1.79s
# 3:	test: 0.9016396	best: 0.9016396 (3)	total: 73.4ms	remaining: 1.76s
# 4:	test: 0.9022570	best: 0.9022570 (4)	total: 89.6ms	remaining: 1.7s
# 5:	test: 0.9030218	best: 0.9030218 (5)	total: 106ms	remaining: 1.67s
# 6:	test: 0.9058898	best: 0.9058898 (6)	total: 125ms	remaining: 1.66s
# 7:	test: 0.9063038	best: 0.9063038 (7)	total: 141ms	remaining: 1.62s
# 8:	test: 0.9066686	best: 0.9066686 (8)	total: 159ms	remaining: 1.6s
# 9:	test: 0.9073337	best: 0.9073337 (9)	total: 179ms	remaining: 1.61s
# 10:	test: 0.9093213	best: 0.9093213 (10)	total: 198ms	remaining: 1.6s
# 11:	test: 0.9097178	best: 0.9097178 (11)	total: 214ms	remaining: 1.57s
# 12:	test: 0.9106860	best: 0.9106860 (12)	total: 230ms	remaining: 1.54s
# 13:	test: 0.9116671	best: 0.9116671 (13)	total: 250ms	remaining: 1.53s
# 14:	test: 0.9121616	best: 0.9121616 (14)	total: 273ms	remaining: 1.55s
# 15:	test: 0.9124972	best: 0.9124972 (15)	total: 302ms	remaining: 1.58s
# 16:	test: 0.9131483	best: 0.9131483 (16)	total: 345ms	remaining: 1.69s
# 17:	test: 0.9133317	best: 0.9133317 (17)	total: 365ms	remaining: 1.66s
# 18:	test: 0.9135439	best: 0.9135439 (18)	total: 385ms	remaining: 1.64s
# 19:	test: 0.9142577	best: 0.9142577 (19)	total: 403ms	remaining: 1.61s
# 20:	test: 0.9143829	best: 0.9143829 (20)	total: 420ms	remaining: 1.58s
# 21:	test: 0.9145186	best: 0.9145186 (21)	total: 435ms	remaining: 1.54s
# 22:	test: 0.9149860	best: 0.9149860 (22)	total: 454ms	remaining: 1.52s
# 23:	test: 0.9150304	best: 0.9150304 (23)	total: 470ms	remaining: 1.49s
# 24:	test: 0.9149168	best: 0.9150304 (23)	total: 489ms	remaining: 1.47s
# 25:	test: 0.9152923	best: 0.9152923 (25)	total: 506ms	remaining: 1.44s
# 26:	test: 0.9152946	best: 0.9152946 (26)	total: 523ms	remaining: 1.41s
# 27:	test: 0.9152674	best: 0.9152946 (26)	total: 541ms	remaining: 1.39s
# 28:	test: 0.9160271	best: 0.9160271 (28)	total: 559ms	remaining: 1.37s
# 29:	test: 0.9160271	best: 0.9160271 (28)	total: 581ms	remaining: 1.35s
# 30:	test: 0.9173850	best: 0.9173850 (30)	total: 612ms	remaining: 1.36s
# 31:	test: 0.9174306	best: 0.9174306 (31)	total: 627ms	remaining: 1.33s
# 32:	test: 0.9180244	best: 0.9180244 (32)	total: 647ms	remaining: 1.31s
# 33:	test: 0.9181897	best: 0.9181897 (33)	total: 668ms	remaining: 1.3s
# 34:	test: 0.9182284	best: 0.9182284 (34)	total: 687ms	remaining: 1.27s
# 35:	test: 0.9182284	best: 0.9182284 (34)	total: 698ms	remaining: 1.24s
# 36:	test: 0.9183761	best: 0.9183761 (36)	total: 713ms	remaining: 1.21s
# 37:	test: 0.9184077	best: 0.9184077 (37)	total: 729ms	remaining: 1.19s
# 38:	test: 0.9186423	best: 0.9186423 (38)	total: 749ms	remaining: 1.17s
# 39:	test: 0.9186529	best: 0.9186529 (39)	total: 764ms	remaining: 1.15s
# 40:	test: 0.9186594	best: 0.9186594 (40)	total: 784ms	remaining: 1.13s
# 41:	test: 0.9187119	best: 0.9187119 (41)	total: 805ms	remaining: 1.11s
# 42:	test: 0.9187083	best: 0.9187119 (41)	total: 825ms	remaining: 1.09s
# 43:	test: 0.9187299	best: 0.9187299 (43)	total: 842ms	remaining: 1.07s
# 44:	test: 0.9187252	best: 0.9187299 (43)	total: 854ms	remaining: 1.04s
# 45:	test: 0.9187338	best: 0.9187338 (45)	total: 868ms	remaining: 1.02s
# 46:	test: 0.9187063	best: 0.9187338 (45)	total: 911ms	remaining: 1.03s
# 47:	test: 0.9187942	best: 0.9187942 (47)	total: 955ms	remaining: 1.03s
# 48:	test: 0.9188590	best: 0.9188590 (48)	total: 979ms	remaining: 1.02s
# 49:	test: 0.9188624	best: 0.9188624 (49)	total: 1s	remaining: 1s
# 50:	test: 0.9188962	best: 0.9188962 (50)	total: 1.03s	remaining: 989ms
# 51:	test: 0.9188983	best: 0.9188983 (51)	total: 1.04s	remaining: 965ms
# 52:	test: 0.9189523	best: 0.9189523 (52)	total: 1.07s	remaining: 947ms
# 53:	test: 0.9190229	best: 0.9190229 (53)	total: 1.09s	remaining: 927ms
# 54:	test: 0.9190517	best: 0.9190517 (54)	total: 1.11s	remaining: 909ms
# 55:	test: 0.9189504	best: 0.9190517 (54)	total: 1.13s	remaining: 891ms
# 56:	test: 0.9188172	best: 0.9190517 (54)	total: 1.16s	remaining: 875ms
# 57:	test: 0.9188172	best: 0.9190517 (54)	total: 1.17s	remaining: 851ms
# 58:	test: 0.9188150	best: 0.9190517 (54)	total: 1.2s	remaining: 836ms
# 59:	test: 0.9188507	best: 0.9190517 (54)	total: 1.23s	remaining: 821ms
# 60:	test: 0.9196443	best: 0.9196443 (60)	total: 1.26s	remaining: 806ms
# 61:	test: 0.9198201	best: 0.9198201 (61)	total: 1.29s	remaining: 790ms
# 62:	test: 0.9198740	best: 0.9198740 (62)	total: 1.32s	remaining: 773ms
# 63:	test: 0.9198371	best: 0.9198740 (62)	total: 1.34s	remaining: 756ms
# 64:	test: 0.9197361	best: 0.9198740 (62)	total: 1.37s	remaining: 739ms
# 65:	test: 0.9198789	best: 0.9198789 (65)	total: 1.4s	remaining: 723ms
# 66:	test: 0.9198864	best: 0.9198864 (66)	total: 1.44s	remaining: 711ms
# 67:	test: 0.9199312	best: 0.9199312 (67)	total: 1.47s	remaining: 693ms
# 68:	test: 0.9200086	best: 0.9200086 (68)	total: 1.5s	remaining: 675ms
# 69:	test: 0.9200018	best: 0.9200086 (68)	total: 1.53s	remaining: 655ms
# 70:	test: 0.9200004	best: 0.9200086 (68)	total: 1.55s	remaining: 634ms
# 71:	test: 0.9199797	best: 0.9200086 (68)	total: 1.57s	remaining: 613ms
# 72:	test: 0.9198766	best: 0.9200086 (68)	total: 1.6s	remaining: 591ms
# 73:	test: 0.9199119	best: 0.9200086 (68)	total: 1.62s	remaining: 569ms
# 74:	test: 0.9199264	best: 0.9200086 (68)	total: 1.64s	remaining: 546ms
# 75:	test: 0.9199370	best: 0.9200086 (68)	total: 1.69s	remaining: 534ms
# 76:	test: 0.9200110	best: 0.9200110 (76)	total: 1.71s	remaining: 511ms
# 77:	test: 0.9200099	best: 0.9200110 (76)	total: 1.73s	remaining: 489ms
# 78:	test: 0.9200327	best: 0.9200327 (78)	total: 1.75s	remaining: 466ms
# 79:	test: 0.9202004	best: 0.9202004 (79)	total: 1.77s	remaining: 444ms
# 80:	test: 0.9202581	best: 0.9202581 (80)	total: 1.8s	remaining: 421ms
# 81:	test: 0.9201854	best: 0.9202581 (80)	total: 1.82s	remaining: 399ms
# 82:	test: 0.9203749	best: 0.9203749 (82)	total: 1.84s	remaining: 377ms
# 83:	test: 0.9203740	best: 0.9203749 (82)	total: 1.86s	remaining: 355ms
# 84:	test: 0.9209800	best: 0.9209800 (84)	total: 1.89s	remaining: 333ms
# 85:	test: 0.9209983	best: 0.9209983 (85)	total: 1.92s	remaining: 312ms
# 86:	test: 0.9210192	best: 0.9210192 (86)	total: 1.94s	remaining: 290ms
# 87:	test: 0.9210034	best: 0.9210192 (86)	total: 1.96s	remaining: 268ms
# 88:	test: 0.9218146	best: 0.9218146 (88)	total: 1.99s	remaining: 246ms
# 89:	test: 0.9217445	best: 0.9218146 (88)	total: 2.01s	remaining: 223ms
# 90:	test: 0.9217567	best: 0.9218146 (88)	total: 2.03s	remaining: 201ms
# 91:	test: 0.9216345	best: 0.9218146 (88)	total: 2.05s	remaining: 179ms
# 92:	test: 0.9216440	best: 0.9218146 (88)	total: 2.07s	remaining: 156ms
# 93:	test: 0.9216650	best: 0.9218146 (88)	total: 2.1s	remaining: 134ms
# 94:	test: 0.9216751	best: 0.9218146 (88)	total: 2.12s	remaining: 111ms
# 95:	test: 0.9216491	best: 0.9218146 (88)	total: 2.14s	remaining: 89.1ms
# 96:	test: 0.9216915	best: 0.9218146 (88)	total: 2.16s	remaining: 66.8ms
# 97:	test: 0.9215654	best: 0.9218146 (88)	total: 2.18s	remaining: 44.5ms
# 98:	test: 0.9215264	best: 0.9218146 (88)	total: 2.2s	remaining: 22.2ms
# 99:	test: 0.9215076	best: 0.9218146 (88)	total: 2.22s	remaining: 0us
#
# bestTest = 0.9218146456
# bestIteration = 88
#
# Training on fold [2/3]
# 0:	test: 0.8924019	best: 0.8924019 (0)	total: 23.4ms	remaining: 2.31s
# 1:	test: 0.8970263	best: 0.8970263 (1)	total: 45.4ms	remaining: 2.23s
# 2:	test: 0.8990643	best: 0.8990643 (2)	total: 67.2ms	remaining: 2.17s
# 3:	test: 0.9058423	best: 0.9058423 (3)	total: 90.2ms	remaining: 2.17s
# 4:	test: 0.9071613	best: 0.9071613 (4)	total: 111ms	remaining: 2.11s
# 5:	test: 0.9079961	best: 0.9079961 (5)	total: 135ms	remaining: 2.12s
# 6:	test: 0.9090501	best: 0.9090501 (6)	total: 157ms	remaining: 2.09s
# 7:	test: 0.9094040	best: 0.9094040 (7)	total: 178ms	remaining: 2.05s
# 8:	test: 0.9095939	best: 0.9095939 (8)	total: 199ms	remaining: 2.01s
# 9:	test: 0.9102354	best: 0.9102354 (9)	total: 218ms	remaining: 1.96s
# 10:	test: 0.9115863	best: 0.9115863 (10)	total: 240ms	remaining: 1.94s
# 11:	test: 0.9133710	best: 0.9133710 (11)	total: 264ms	remaining: 1.94s
# 12:	test: 0.9137462	best: 0.9137462 (12)	total: 283ms	remaining: 1.9s
# 13:	test: 0.9140843	best: 0.9140843 (13)	total: 304ms	remaining: 1.87s
# 14:	test: 0.9142931	best: 0.9142931 (14)	total: 325ms	remaining: 1.84s
# 15:	test: 0.9152042	best: 0.9152042 (15)	total: 358ms	remaining: 1.88s
# 16:	test: 0.9156152	best: 0.9156152 (16)	total: 383ms	remaining: 1.87s
# 17:	test: 0.9156540	best: 0.9156540 (17)	total: 404ms	remaining: 1.84s
# 18:	test: 0.9156408	best: 0.9156540 (17)	total: 424ms	remaining: 1.81s
# 19:	test: 0.9166895	best: 0.9166895 (19)	total: 447ms	remaining: 1.79s
# 20:	test: 0.9175986	best: 0.9175986 (20)	total: 469ms	remaining: 1.76s
# 21:	test: 0.9177419	best: 0.9177419 (21)	total: 491ms	remaining: 1.74s
# 22:	test: 0.9180086	best: 0.9180086 (22)	total: 512ms	remaining: 1.71s
# 23:	test: 0.9179363	best: 0.9180086 (22)	total: 535ms	remaining: 1.69s
# 24:	test: 0.9189492	best: 0.9189492 (24)	total: 558ms	remaining: 1.67s
# 25:	test: 0.9193932	best: 0.9193932 (25)	total: 584ms	remaining: 1.66s
# 26:	test: 0.9194840	best: 0.9194840 (26)	total: 603ms	remaining: 1.63s
# 27:	test: 0.9195695	best: 0.9195695 (27)	total: 617ms	remaining: 1.59s
# 28:	test: 0.9197271	best: 0.9197271 (28)	total: 632ms	remaining: 1.55s
# 29:	test: 0.9198082	best: 0.9198082 (29)	total: 648ms	remaining: 1.51s
# 30:	test: 0.9198041	best: 0.9198082 (29)	total: 664ms	remaining: 1.48s
# 31:	test: 0.9202419	best: 0.9202419 (31)	total: 683ms	remaining: 1.45s
# 32:	test: 0.9202798	best: 0.9202798 (32)	total: 698ms	remaining: 1.42s
# 33:	test: 0.9203703	best: 0.9203703 (33)	total: 713ms	remaining: 1.38s
# 34:	test: 0.9205769	best: 0.9205769 (34)	total: 727ms	remaining: 1.35s
# 35:	test: 0.9206070	best: 0.9206070 (35)	total: 744ms	remaining: 1.32s
# 36:	test: 0.9206469	best: 0.9206469 (36)	total: 760ms	remaining: 1.29s
# 37:	test: 0.9214121	best: 0.9214121 (37)	total: 779ms	remaining: 1.27s
# 38:	test: 0.9214488	best: 0.9214488 (38)	total: 796ms	remaining: 1.25s
# 39:	test: 0.9213609	best: 0.9214488 (38)	total: 814ms	remaining: 1.22s
# 40:	test: 0.9214051	best: 0.9214488 (38)	total: 827ms	remaining: 1.19s
# 41:	test: 0.9217311	best: 0.9217311 (41)	total: 843ms	remaining: 1.16s
# 42:	test: 0.9218931	best: 0.9218931 (42)	total: 860ms	remaining: 1.14s
# 43:	test: 0.9219084	best: 0.9219084 (43)	total: 874ms	remaining: 1.11s
# 44:	test: 0.9220218	best: 0.9220218 (44)	total: 890ms	remaining: 1.09s
# 45:	test: 0.9220302	best: 0.9220302 (45)	total: 906ms	remaining: 1.06s
# 46:	test: 0.9220903	best: 0.9220903 (46)	total: 924ms	remaining: 1.04s
# 47:	test: 0.9221044	best: 0.9221044 (47)	total: 939ms	remaining: 1.02s
# 48:	test: 0.9223263	best: 0.9223263 (48)	total: 957ms	remaining: 996ms
# 49:	test: 0.9223081	best: 0.9223263 (48)	total: 976ms	remaining: 976ms
# 50:	test: 0.9222631	best: 0.9223263 (48)	total: 992ms	remaining: 953ms
# 51:	test: 0.9221480	best: 0.9223263 (48)	total: 1.01s	remaining: 929ms
# 52:	test: 0.9221534	best: 0.9223263 (48)	total: 1.02s	remaining: 905ms
# 53:	test: 0.9222019	best: 0.9223263 (48)	total: 1.04s	remaining: 883ms
# 54:	test: 0.9222750	best: 0.9223263 (48)	total: 1.05s	remaining: 861ms
# 55:	test: 0.9223076	best: 0.9223263 (48)	total: 1.06s	remaining: 837ms
# 56:	test: 0.9223606	best: 0.9223606 (56)	total: 1.08s	remaining: 816ms
# 57:	test: 0.9221938	best: 0.9223606 (56)	total: 1.1s	remaining: 795ms
# 58:	test: 0.9221904	best: 0.9223606 (56)	total: 1.11s	remaining: 774ms
# 59:	test: 0.9225450	best: 0.9225450 (59)	total: 1.13s	remaining: 754ms
# 60:	test: 0.9225473	best: 0.9225473 (60)	total: 1.15s	remaining: 733ms
# 61:	test: 0.9225809	best: 0.9225809 (61)	total: 1.17s	remaining: 715ms
# 62:	test: 0.9227084	best: 0.9227084 (62)	total: 1.18s	remaining: 695ms
# 63:	test: 0.9226849	best: 0.9227084 (62)	total: 1.2s	remaining: 675ms
# 64:	test: 0.9226789	best: 0.9227084 (62)	total: 1.22s	remaining: 654ms
# 65:	test: 0.9227100	best: 0.9227100 (65)	total: 1.23s	remaining: 634ms
# 66:	test: 0.9227136	best: 0.9227136 (66)	total: 1.24s	remaining: 611ms
# 67:	test: 0.9227897	best: 0.9227897 (67)	total: 1.25s	remaining: 591ms
# 68:	test: 0.9228248	best: 0.9228248 (68)	total: 1.27s	remaining: 571ms
# 69:	test: 0.9231155	best: 0.9231155 (69)	total: 1.29s	remaining: 553ms
# 70:	test: 0.9231498	best: 0.9231498 (70)	total: 1.3s	remaining: 533ms
# 71:	test: 0.9231597	best: 0.9231597 (71)	total: 1.32s	remaining: 516ms
# 72:	test: 0.9231686	best: 0.9231686 (72)	total: 1.34s	remaining: 496ms
# 73:	test: 0.9231924	best: 0.9231924 (73)	total: 1.36s	remaining: 477ms
# 74:	test: 0.9232586	best: 0.9232586 (74)	total: 1.37s	remaining: 458ms
# 75:	test: 0.9232220	best: 0.9232586 (74)	total: 1.4s	remaining: 442ms
# 76:	test: 0.9232256	best: 0.9232586 (74)	total: 1.42s	remaining: 423ms
# 77:	test: 0.9232749	best: 0.9232749 (77)	total: 1.43s	remaining: 404ms
# 78:	test: 0.9233470	best: 0.9233470 (78)	total: 1.45s	remaining: 386ms
# 79:	test: 0.9233613	best: 0.9233613 (79)	total: 1.47s	remaining: 367ms
# 80:	test: 0.9234831	best: 0.9234831 (80)	total: 1.48s	remaining: 348ms
# 81:	test: 0.9235362	best: 0.9235362 (81)	total: 1.5s	remaining: 330ms
# 82:	test: 0.9235615	best: 0.9235615 (82)	total: 1.52s	remaining: 312ms
# 83:	test: 0.9234674	best: 0.9235615 (82)	total: 1.54s	remaining: 293ms
# 84:	test: 0.9234847	best: 0.9235615 (82)	total: 1.56s	remaining: 275ms
# 85:	test: 0.9234711	best: 0.9235615 (82)	total: 1.57s	remaining: 256ms
# 86:	test: 0.9234743	best: 0.9235615 (82)	total: 1.59s	remaining: 238ms
# 87:	test: 0.9236547	best: 0.9236547 (87)	total: 1.61s	remaining: 220ms
# 88:	test: 0.9237491	best: 0.9237491 (88)	total: 1.63s	remaining: 201ms
# 89:	test: 0.9237948	best: 0.9237948 (89)	total: 1.65s	remaining: 183ms
# 90:	test: 0.9238374	best: 0.9238374 (90)	total: 1.66s	remaining: 164ms
# 91:	test: 0.9238156	best: 0.9238374 (90)	total: 1.68s	remaining: 146ms
# 92:	test: 0.9238535	best: 0.9238535 (92)	total: 1.69s	remaining: 127ms
# 93:	test: 0.9244917	best: 0.9244917 (93)	total: 1.71s	remaining: 109ms
# 94:	test: 0.9245792	best: 0.9245792 (94)	total: 1.73s	remaining: 90.9ms
# 95:	test: 0.9246059	best: 0.9246059 (95)	total: 1.75s	remaining: 72.8ms
# 96:	test: 0.9246047	best: 0.9246059 (95)	total: 1.76s	remaining: 54.6ms
# 97:	test: 0.9246205	best: 0.9246205 (97)	total: 1.78s	remaining: 36.3ms
# 98:	test: 0.9246798	best: 0.9246798 (98)	total: 1.8s	remaining: 18.2ms
# 99:	test: 0.9247666	best: 0.9247666 (99)	total: 1.82s	remaining: 0us
#
# bestTest = 0.9247665828
# bestIteration = 99

# %% [markdown]
# ## Comparison of models

# %% [markdown]
# After selecting optimal parameters there was time for comparison part. Using best models for each algorithm the mean cross validation score was calculated. There are three different results taken into account, accuracy, roc_auc score and f1 score. Based on them the final algorithm was selected which will be more developed in next sections.

# %%
f = open('search_grid_results.pkl', 'rb')
best_models = pickle.load(f)
f.close()

# %%
eval_table = pd.DataFrame(np.zeros((3, len(best_models.keys()))), index=["Accuracy", "ROC_AUC", "F1-score"], columns=best_models.keys())

for key in best_models.keys():
    if key=="catboost":
        params = {"random_state": 2023, "iterations": 100, "eval_metric": 'Accuracy',  "loss_function": "Logloss", "scale_pos_weight": 3,}
        params.update(best_models["catboost"])
        
        scores = cb.cv(train_dataset,params, fold_count=3, verbose=False)
        eval_table.loc["Accuracy", key] = np.mean(scores["test-Accuracy-mean"])
        
        params["eval_metric"] = "AUC"
        scores = cb.cv(train_dataset,params, fold_count=2, plot="True", verbose=False)
        eval_table.loc["ROC_AUC", key] = np.mean(scores["test-AUC-mean"])
        
        params["eval_metric"] = "F1"
        scores = cb.cv(train_dataset,params, fold_count=2, verbose=False)
        eval_table.loc["F1-score", key] = np.mean(scores["test-F1-mean"])
    else:
        eval_table.loc["Accuracy", key] = np.mean(cross_val_score(best_models[key], X_train, y_train, scoring="accuracy", cv=3))
        eval_table.loc["ROC_AUC", key] = np.mean(cross_val_score(best_models[key], X_train, y_train, scoring="roc_auc", cv=3))
        eval_table.loc["F1-score", key] = np.mean(cross_val_score(best_models[key], X_train, y_train, scoring="f1", cv=3))

eval_table
# Out:
# Training on fold [0/3]
#
# bestTest = 0.832379459
# bestIteration = 85
#
# Training on fold [1/3]
#
# bestTest = 0.8319479297
# bestIteration = 87
#
# Training on fold [2/3]
#
# bestTest = 0.8356336261
# bestIteration = 98
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/2]
#
# bestTest = 0.9143569402
# bestIteration = 91
#
# Training on fold [1/2]
#
# bestTest = 0.9160982861
# bestIteration = 99
#
# Training on fold [0/2]
#
# bestTest = 0.8300395257
# bestIteration = 74
#
# Training on fold [1/2]
#
# bestTest = 0.8314226848
# bestIteration = 58
#                knn      tree       ada  random_forest  catboost
# Accuracy  0.788743  0.788858  0.859458       0.834304  0.829684
# ROC_AUC   0.888908  0.890098  0.921605       0.884193  0.912568
# F1-score  0.655684  0.657128  0.712332       0.657926  0.827620

# %% [markdown]
# Based on the results we can notice that boosting algorithms received the highest scores as it was expected. But surprisingly the KNN and DecisiionTree algorithms were very close to these advanced ones. Ultimately, the CatBoost has been selected as it had similar Accuracy and ROC_AUC scores as AdaBoost but had better F1 statistic in comparison to others. Therefore, the fitting method where testing dataset was used as an eval_set.

# %% [markdown]
# ## Calibration

# %% [markdown]
# Usually, models that try to predict binary probabilities tend to assign extreme probabilities, close to 1 or 0, for each observation. It means that they are not well distributed. This issue doesn't apply to probabilistic models. However, to solve it in other models the calibration is required. Therefore it was decided to use the CalibratedClassifierCV class from sklearn library with our CatBoost classifier. For comparison purposes the calibration plot was created below. We can notice that uncalibrated CatBoost was behaving relatively well, however after calibration it was very close to perfectly calibrated models.

# %%
f = open('search_grid_results.pkl', 'rb')
best_models = pickle.load(f)
f.close()
params = {"random_state": 2023, "iterations": 100, "eval_metric": 'AUC',  "loss_function": "Logloss", "scale_pos_weight": 3}
params.update(best_models["catboost"])

classifier = CatBoostClassifier(**params)
classifier.fit(X_train_cat, y_train, eval_set=test_dataset, cat_features=unencodeded_categoric)
model_cal = CalibratedClassifierCV(estimator=classifier,cv='prefit')
model_cal.fit(X_train_cat,y_train)

fig = plt.figure(figsize=(10, 10))
gs = GridSpec(4, 2)
colors = plt.cm.get_cmap("Dark2")

ax_calibration_curve = fig.add_subplot(gs[:2, :2])
calibration_displays = {}
markers = ["^", "v"]

clf_list = [
    (classifier, "CatBoost uncalibrated"),
    (model_cal, "CatBoost calibrated")
]

for i, (clf, name) in enumerate(clf_list):
    display = CalibrationDisplay.from_estimator(
        clf,
        X_test_cat,
        y_test,
        n_bins=10,
        name=name,
        ax=ax_calibration_curve,
        color=colors(i),
        marker=markers[i],
    )
    calibration_displays[name] = display

ax_calibration_curve.grid()
ax_calibration_curve.set_title("Calibration plots")
plt.show()
# Out:
# 0:	test: 0.8918945	best: 0.8918945 (0)	total: 10.1ms	remaining: 997ms
# 1:	test: 0.8950606	best: 0.8950606 (1)	total: 19.4ms	remaining: 949ms
# 2:	test: 0.8965096	best: 0.8965096 (2)	total: 27.6ms	remaining: 891ms
# 3:	test: 0.8982898	best: 0.8982898 (3)	total: 35.3ms	remaining: 848ms
# 4:	test: 0.8992592	best: 0.8992592 (4)	total: 43.4ms	remaining: 824ms
# 5:	test: 0.9028370	best: 0.9028370 (5)	total: 50.7ms	remaining: 794ms
# 6:	test: 0.9043928	best: 0.9043928 (6)	total: 58.4ms	remaining: 776ms
# 7:	test: 0.9056716	best: 0.9056716 (7)	total: 66.3ms	remaining: 763ms
# 8:	test: 0.9069790	best: 0.9069790 (8)	total: 74.9ms	remaining: 758ms
# 9:	test: 0.9073855	best: 0.9073855 (9)	total: 82.7ms	remaining: 744ms
# 10:	test: 0.9071788	best: 0.9073855 (9)	total: 90.8ms	remaining: 735ms
# 11:	test: 0.9077101	best: 0.9077101 (11)	total: 98ms	remaining: 719ms
# 12:	test: 0.9081452	best: 0.9081452 (12)	total: 106ms	remaining: 711ms
# 13:	test: 0.9085845	best: 0.9085845 (13)	total: 114ms	remaining: 699ms
# 14:	test: 0.9089106	best: 0.9089106 (14)	total: 123ms	remaining: 698ms
# 15:	test: 0.9093767	best: 0.9093767 (15)	total: 130ms	remaining: 681ms
# 16:	test: 0.9097396	best: 0.9097396 (16)	total: 137ms	remaining: 671ms
# 17:	test: 0.9106935	best: 0.9106935 (17)	total: 145ms	remaining: 660ms
# 18:	test: 0.9111962	best: 0.9111962 (18)	total: 153ms	remaining: 651ms
# 19:	test: 0.9115158	best: 0.9115158 (19)	total: 163ms	remaining: 653ms
# 20:	test: 0.9116644	best: 0.9116644 (20)	total: 173ms	remaining: 652ms
# 21:	test: 0.9119858	best: 0.9119858 (21)	total: 180ms	remaining: 640ms
# 22:	test: 0.9125915	best: 0.9125915 (22)	total: 190ms	remaining: 636ms
# 23:	test: 0.9130386	best: 0.9130386 (23)	total: 197ms	remaining: 624ms
# 24:	test: 0.9134268	best: 0.9134268 (24)	total: 204ms	remaining: 612ms
# 25:	test: 0.9136495	best: 0.9136495 (25)	total: 214ms	remaining: 609ms
# 26:	test: 0.9139048	best: 0.9139048 (26)	total: 224ms	remaining: 605ms
# 27:	test: 0.9145160	best: 0.9145160 (27)	total: 239ms	remaining: 614ms
# 28:	test: 0.9147158	best: 0.9147158 (28)	total: 250ms	remaining: 613ms
# 29:	test: 0.9147833	best: 0.9147833 (29)	total: 261ms	remaining: 609ms
# 30:	test: 0.9150707	best: 0.9150707 (30)	total: 274ms	remaining: 611ms
# 31:	test: 0.9153116	best: 0.9153116 (31)	total: 284ms	remaining: 603ms
# 32:	test: 0.9154310	best: 0.9154310 (32)	total: 294ms	remaining: 598ms
# 33:	test: 0.9157061	best: 0.9157061 (33)	total: 305ms	remaining: 592ms
# 34:	test: 0.9160054	best: 0.9160054 (34)	total: 317ms	remaining: 589ms
# 35:	test: 0.9162381	best: 0.9162381 (35)	total: 325ms	remaining: 578ms
# 36:	test: 0.9162816	best: 0.9162816 (36)	total: 335ms	remaining: 571ms
# 37:	test: 0.9166208	best: 0.9166208 (37)	total: 347ms	remaining: 566ms
# 38:	test: 0.9168682	best: 0.9168682 (38)	total: 358ms	remaining: 560ms
# 39:	test: 0.9168154	best: 0.9168682 (38)	total: 367ms	remaining: 550ms
# 40:	test: 0.9167813	best: 0.9168682 (38)	total: 377ms	remaining: 542ms
# 41:	test: 0.9169872	best: 0.9169872 (41)	total: 390ms	remaining: 538ms
# 42:	test: 0.9171855	best: 0.9171855 (42)	total: 401ms	remaining: 532ms
# 43:	test: 0.9172409	best: 0.9172409 (43)	total: 411ms	remaining: 523ms
# 44:	test: 0.9172920	best: 0.9172920 (44)	total: 423ms	remaining: 518ms
# 45:	test: 0.9173826	best: 0.9173826 (45)	total: 433ms	remaining: 508ms
# 46:	test: 0.9175016	best: 0.9175016 (46)	total: 444ms	remaining: 501ms
# 47:	test: 0.9175016	best: 0.9175016 (46)	total: 449ms	remaining: 486ms
# 48:	test: 0.9174594	best: 0.9175016 (46)	total: 459ms	remaining: 478ms
# 49:	test: 0.9174781	best: 0.9175016 (46)	total: 467ms	remaining: 467ms
# 50:	test: 0.9175496	best: 0.9175496 (50)	total: 476ms	remaining: 458ms
# 51:	test: 0.9176838	best: 0.9176838 (51)	total: 483ms	remaining: 446ms
# 52:	test: 0.9177649	best: 0.9177649 (52)	total: 493ms	remaining: 437ms
# 53:	test: 0.9178394	best: 0.9178394 (53)	total: 503ms	remaining: 429ms
# 54:	test: 0.9177742	best: 0.9178394 (53)	total: 511ms	remaining: 418ms
# 55:	test: 0.9177601	best: 0.9178394 (53)	total: 518ms	remaining: 407ms
# 56:	test: 0.9178358	best: 0.9178394 (53)	total: 525ms	remaining: 396ms
# 57:	test: 0.9178349	best: 0.9178394 (53)	total: 530ms	remaining: 384ms
# 58:	test: 0.9178348	best: 0.9178394 (53)	total: 540ms	remaining: 375ms
# 59:	test: 0.9179009	best: 0.9179009 (59)	total: 549ms	remaining: 366ms
# 60:	test: 0.9180198	best: 0.9180198 (60)	total: 558ms	remaining: 357ms
# 61:	test: 0.9180173	best: 0.9180198 (60)	total: 568ms	remaining: 348ms
# 62:	test: 0.9180229	best: 0.9180229 (62)	total: 575ms	remaining: 338ms
# 63:	test: 0.9183086	best: 0.9183086 (63)	total: 586ms	remaining: 330ms
# 64:	test: 0.9183007	best: 0.9183086 (63)	total: 594ms	remaining: 320ms
# 65:	test: 0.9183846	best: 0.9183846 (65)	total: 603ms	remaining: 311ms
# 66:	test: 0.9183903	best: 0.9183903 (66)	total: 609ms	remaining: 300ms
# 67:	test: 0.9183995	best: 0.9183995 (67)	total: 615ms	remaining: 290ms
# 68:	test: 0.9183803	best: 0.9183995 (67)	total: 622ms	remaining: 279ms
# 69:	test: 0.9185904	best: 0.9185904 (69)	total: 632ms	remaining: 271ms
# 70:	test: 0.9185929	best: 0.9185929 (70)	total: 641ms	remaining: 262ms
# 71:	test: 0.9187527	best: 0.9187527 (71)	total: 652ms	remaining: 254ms
# 72:	test: 0.9187930	best: 0.9187930 (72)	total: 659ms	remaining: 244ms
# 73:	test: 0.9187651	best: 0.9187930 (72)	total: 665ms	remaining: 234ms
# 74:	test: 0.9187678	best: 0.9187930 (72)	total: 671ms	remaining: 224ms
# 75:	test: 0.9187290	best: 0.9187930 (72)	total: 677ms	remaining: 214ms
# 76:	test: 0.9187301	best: 0.9187930 (72)	total: 683ms	remaining: 204ms
# 77:	test: 0.9187301	best: 0.9187930 (72)	total: 689ms	remaining: 194ms
# 78:	test: 0.9187934	best: 0.9187934 (78)	total: 695ms	remaining: 185ms
# 79:	test: 0.9189235	best: 0.9189235 (79)	total: 705ms	remaining: 176ms
# 80:	test: 0.9189427	best: 0.9189427 (80)	total: 712ms	remaining: 167ms
# 81:	test: 0.9189379	best: 0.9189427 (80)	total: 719ms	remaining: 158ms
# 82:	test: 0.9189569	best: 0.9189569 (82)	total: 725ms	remaining: 149ms
# 83:	test: 0.9189573	best: 0.9189573 (83)	total: 732ms	remaining: 139ms
# 84:	test: 0.9189592	best: 0.9189592 (84)	total: 738ms	remaining: 130ms
# 85:	test: 0.9189243	best: 0.9189592 (84)	total: 745ms	remaining: 121ms
# 86:	test: 0.9189291	best: 0.9189592 (84)	total: 751ms	remaining: 112ms
# 87:	test: 0.9189283	best: 0.9189592 (84)	total: 760ms	remaining: 104ms
# 88:	test: 0.9189505	best: 0.9189592 (84)	total: 767ms	remaining: 94.8ms
# 89:	test: 0.9189507	best: 0.9189592 (84)	total: 775ms	remaining: 86.1ms
# 90:	test: 0.9189559	best: 0.9189592 (84)	total: 782ms	remaining: 77.4ms
# 91:	test: 0.9189777	best: 0.9189777 (91)	total: 788ms	remaining: 68.5ms
# 92:	test: 0.9189877	best: 0.9189877 (92)	total: 795ms	remaining: 59.8ms
# 93:	test: 0.9190555	best: 0.9190555 (93)	total: 804ms	remaining: 51.3ms
# 94:	test: 0.9190640	best: 0.9190640 (94)	total: 809ms	remaining: 42.6ms
# 95:	test: 0.9190642	best: 0.9190642 (95)	total: 815ms	remaining: 34ms
# 96:	test: 0.9190611	best: 0.9190642 (95)	total: 821ms	remaining: 25.4ms
# 97:	test: 0.9190744	best: 0.9190744 (97)	total: 830ms	remaining: 16.9ms
# 98:	test: 0.9190414	best: 0.9190744 (97)	total: 836ms	remaining: 8.44ms
# 99:	test: 0.9190514	best: 0.9190744 (97)	total: 841ms	remaining: 0us
#
# bestTest = 0.9190744093
# bestIteration = 97
#
# Shrink model to first 98 iterations.
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/sklearn/calibration.py:1176: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s-" (-> marker='s'). The keyword argument will take precedence.
#   self.line_ = ax.plot(self.prob_pred, self.prob_true, "s-", **line_kwargs)[0]
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/sklearn/calibration.py:1176: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "s-" (-> marker='s'). The keyword argument will take precedence.
#   self.line_ = ax.plot(self.prob_pred, self.prob_true, "s-", **line_kwargs)[0]

# %% [markdown]
# # Profit Estimations

# %% [markdown]
# In this part of the project the estimations for potential customers were predicted. But before it was necessary to preprocess data.

# %%
FINAL_DATA_PATH = "data/potential-customers.xlsx"
final_data = pd.read_excel(FINAL_DATA_PATH)

customers_id = final_data["RowID"]

nas_count = final_data.isna().sum(axis = 0)

final_data.rename(columns = {'education-num':'education_num', 'marital-status':'marital_status', 'native-country': 'native_country',
                            'capital-gain':'capital_gain', 'capital-loss': 'capital_loss', 'hours-per-week': "hours_per_week"}, inplace = True)

# Preprocessing
gov = ["Local-gov", "State-gov", "Federal-gov"]
final_data["workclass"] = final_data["workclass"].apply(lambda x: "Gov" if x in gov else x)

compulsory = ["11th", "9th", "7th-8th", "5th-6th", "10th", "1st-4th", "12th", "Preschool"]
final_data["education"] = final_data["education"].apply(lambda x: "Compulsory" if x in compulsory else x)

assoc = ["Assoc-voc", "Assoc-acdm"]
final_data["education"] = final_data["education"].apply(lambda x: "Associate" if x in assoc else x)

race = ["Black", "Asian-Pac-Islander", "Amer-Indian-Eskimo", "Other"]
final_data["race"] = final_data["race"].apply(lambda x: "Other" if x in race else x)

final_data = final_data.drop(columns=["native_country", "RowID", "education_num"])

nas_count = final_data.isna().sum(axis = 0)
for indx in nas_count[nas_count>0].index:
    md = mode(final_data[indx])
    final_data[indx] = final_data[indx].fillna(md.mode[0])
# Out:
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3107905274.py:28: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   md = mode(final_data[indx])
# /Users/karol/.pyenv/versions/3.10.6/envs/DMenv/lib/python3.10/site-packages/scipy/stats/_stats_py.py:112: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# /var/folders/cl/rrx_9t192b9328xy7nz8dc580000gn/T/ipykernel_23717/3107905274.py:28: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   md = mode(final_data[indx])

# %% [markdown]
# Now the probabilities of belonging to a proper class were estimated. Then, based on them the expected profit was calculated. To do that I needed to establish a proper threshold which would allow to maximize the expected profit.

# %%
probs = model_cal.predict_proba(final_data)
final_results = {"prob_threshold": 0.01, "expected_profit": 0}
positive_reaction_prob = probs* [0.05, 0.1]
expected_value = positive_reaction_prob.dot([-340, 980])

for threshold in np.arange(0.01, 1, 0.01):
    profit = np.sum(expected_value[probs[:,0]<threshold]) - 10 * np.sum(probs[:,0]<threshold)
    if profit > final_results["expected_profit"]:
        final_results["prob_threshold"] = threshold
        final_results["expected_profit"] = profit

print(final_results)
# Out:
# {'prob_threshold': 0.77, 'expected_profit': 246122.8705409931}

# %% [markdown]
# Below the final list of potential customers have been established.

# %%
customers = customers_id[probs[:,0]<final_results["prob_threshold"]]
customers.to_csv('customers.txt', sep=',', index=False)
